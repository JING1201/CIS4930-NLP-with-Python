# %%
import nltk
import inflect

# %%
from nltk.corpus import brown
all_tagged_nouns = [(w.lower(), tag) for (w, tag) in brown.tagged_words() if 
             (tag.startswith('NN') or tag.startswith('NNS') or tag.startswith('NP') or tag.startswith('NPS')) 
            and not (tag.startswith('NN$') or tag.startswith('NP$') or tag.startswith('NPS$') or tag.startswith('NNS$'))]
all_nouns = [w for (w, tag) in all_tagged_nouns]
noun_set = set(all_nouns)
# getting only singular and plural common and proper nouns

# %%
fq_nouns = nltk.FreqDist(all_nouns)
inf = inflect.engine()

# %%
ans = set()
for w in list(noun_set):
    if inf.singular_noun(w) is False: #if noun is singular (because it cannot be converted to plural)
        plural_w = inf.plural_noun(w)
        if fq_nouns[plural_w] > fq_nouns[w]:
            ans.add ((w, plural_w))
    else:
        singular_w = inf.singular_noun(w)
        if fq_nouns[singular_w] < fq_nouns[w]:
            ans.add ((singular_w, w))

# %%
ans
# Out:
# {('diver', 'divers'),
#  ('cantilever', 'cantilevers'),
#  ('export', 'exports'),
#  ('watcher', 'watchers'),
#  ('grape', 'grapes'),
#  ('quakeres', 'quakeress'),
#  ('mineral', 'minerals'),
#  ('busynes', 'busyness'),
#  ('wrestling', 'wrestlings'),
#  ('appaloosa', 'appaloosas'),
#  ('novum', 'nova'),
#  ('aegi', 'aegis'),
#  ('stilt', 'stilts'),
#  ('ruminant', 'ruminants'),
#  ('spiritual', 'spirituals'),
#  ('steeler', 'steelers'),
#  ('belonging', 'belongings'),
#  ('guffaw', 'guffaws'),
#  ('surfacenes', 'surfaceness'),
#  ('tirade', 'tirades'),
#  ('leak', 'leaks'),
#  ('naturalnes', 'naturalness'),
#  ('spring-joint', 'spring-joints'),
#  ('traineeship', 'traineeships'),
#  ('25-cent', '25-cents'),
#  ('withe', 'withes'),
#  ('lightnes', 'lightness'),
#  ('outlander', 'outlanders'),
#  ('thill', 'thills'),
#  ('augustu', 'augustus'),
#  ('portent', 'portents'),
#  ('cowrtier', 'cowrtiers'),
#  ('dai', 'dais'),
#  ('nothing', 'nothings'),
#  ('henchman', 'henchmen'),
#  ('surrealist', 'surrealists'),
#  ('parent', 'parents'),
#  ('finger-tip', 'finger-tips'),
#  ('glycoside', 'glycosides'),
#  ('gras', 'grass'),
#  ('torpetiu', 'torpetius'),
#  ('gedde', 'geddes'),
#  ('rhino', 'rhinos'),
#  ('locu', 'locus'),
#  ('modification', 'modifications'),
#  ('commodity', 'commodities'),
#  ('essayist', 'essayists'),
#  ("t'", "t's"),
#  ('giggle', 'giggles'),
#  ('awarenes', 'awareness'),
#  ("cdc'", "cdc's"),
#  ('step', 'steps'),
#  ('probe', 'probes'),
#  ('protease', 'proteases'),
#  ('responsivenes', 'responsiveness'),
#  ('defensivenes', 'defensiveness'),
#  ('acces', 'access'),
#  ('eighty', 'eighties'),
#  ('ellipsoid', 'ellipsoids'),
#  ('mutation', 'mutations'),
#  ('osteoporosi', 'osteoporosis'),
#  ('intercrisi', 'intercrisis'),
#  ('mid-fifty', 'mid-fifties'),
#  ('psychologist', 'psychologists'),
#  ('tenement', 'tenements'),
#  ('spoilable', 'spoilables'),
#  ("doctor'", "doctor's"),
#  ('colonial', 'colonials'),
#  ('vicissitude', 'vicissitudes'),
#  ('kelt', 'kelts'),
#  ('sedan', 'sedans'),
#  ('thespian', 'thespians'),
#  ('credential', 'credentials'),
#  ('theatre-by-the sea', 'theatre-by-the-sea'),
#  ('brainard', 'brainards'),
#  ('short', 'shorts'),
#  ('geologist', 'geologists'),
#  ('orchard', 'orchards'),
#  ('pseudo-happines', 'pseudo-happiness'),
#  ('foolishnes', 'foolishness'),
#  ('isopleth', 'isopleths'),
#  ('organ', 'organs'),
#  ('word-game', 'word-games'),
#  ("b-47'", "b-47's"),
#  ('pillar', 'pillars'),
#  ('rupee', 'rupees'),
#  ('hodge', 'hodges'),
#  ('steffen', 'steffens'),
#  ('anti-semite', 'anti-semites'),
#  ('deadlines', 'deadliness'),
#  ('his', 'hiss'),
#  ('1970', '1970s'),
#  ('prowes', 'prowess'),
#  ('table-tenni', 'table-tennis'),
#  ('fortification', 'fortifications'),
#  ('restorer', 'restorers'),
#  ('gene-princes', 'gene-princess'),
#  ('utopian', 'utopians'),
#  ('pb', 'pbs'),
#  ('banker', 'bankers'),
#  ('smallnes', 'smallness'),
#  ('ey', 'eies'),
#  ('electres', 'electress'),
#  ('air-drift', 'air-drifts'),
#  ('yokut', 'yokuts'),
#  ("icbm'", "icbm's"),
#  ('homesteader', 'homesteaders'),
#  ('berliner', 'berliners'),
#  ('additive', 'additives'),
#  ('messr', 'messrs'),
#  ('cosmetic', 'cosmetics'),
#  ("rob'", "rob's"),
#  ('radioman', 'radiomen'),
#  ('balkines', 'balkiness'),
#  ('generalist', 'generalists'),
#  ('miliari', 'miliaris'),
#  ('sniveling', 'snivelings'),
#  ('shortsightednes', 'shortsightedness'),
#  ('brothel', 'brothels'),
#  ('directnes', 'directness'),
#  ('experiment', 'experiments'),
#  ('ditmar', 'ditmars'),
#  ('serviceman', 'servicemen'),
#  ('arrangement', 'arrangements'),
#  ('90-degree', '90-degrees'),
#  ('paulu', 'paulus'),
#  ('orderlines', 'orderliness'),
#  ('forgivenes', 'forgiveness'),
#  ('mourner', 'mourners'),
#  ('evocation', 'evocations'),
#  ('public-addres', 'public-address'),
#  ('sweetnes', 'sweetness'),
#  ('motorscooter', 'motorscooters'),
#  ('forgetfulnes', 'forgetfulness'),
#  ('cypres', 'cypress'),
#  ('vibe', 'vibes'),
#  ('affiliate', 'affiliates'),
#  ('prayer-request', 'prayer-requests'),
#  ('jani', 'janis'),
#  ('newly-wed', 'newly-weds'),
#  ('escapade', 'escapades'),
#  ('carcas', 'carcass'),
#  ('endearment', 'endearments'),
#  ('opus', 'opera'),
#  ('predisposition', 'predispositions'),
#  ('breastwork', 'breastworks'),
#  ('jeffersonian', 'jeffersonians'),
#  ('landi', 'landis'),
#  ('rollin', 'rollins'),
#  ('tabloid', 'tabloids'),
#  ('acropoli', 'acropolis'),
#  ('jura', 'juras'),
#  ("1840'", "1840's"),
#  ('pesticide', 'pesticides'),
#  ('paragraph', 'paragraphs'),
#  ('mise', 'mises'),
#  ('mutterer', 'mutterers'),
#  ('hatter', 'hatters'),
#  ('obligation', 'obligations'),
#  ('tormenter', 'tormenters'),
#  ('channel', 'channels'),
#  ('value-problem', 'value-problems'),
#  ('inwardnes', 'inwardness'),
#  ('cp', 'cps'),
#  ('charge-exces', 'charge-excess'),
#  ('fungicide', 'fungicides'),
#  ('mathue', 'mathues'),
#  ('minn', 'minns'),
#  ('strangenes', 'strangeness'),
#  ('somer', 'somers'),
#  ('arm', 'arms'),
#  ('ethic', 'ethics'),
#  ('blacknes', 'blackness'),
#  ('bubble', 'bubbles'),
#  ('meditation', 'meditations'),
#  ("mid-1950'", "mid-1950's"),
#  ('perkin', 'perkins'),
#  ('painting', 'paintings'),
#  ('guiltines', 'guiltiness'),
#  ('aberration', 'aberrations'),
#  ('bricklayer', 'bricklayers'),
#  ('madnes', 'madness'),
#  ('accession', 'accessions'),
#  ('gidding', 'giddings'),
#  ("k'", "k's"),
#  ('ter-stepanovum', 'ter-stepanova'),
#  ("mp'", "mp's"),
#  ('optic', 'optics'),
#  ('grammarian', 'grammarians'),
#  ('italian', 'italians'),
#  ('carolinian', 'carolinians'),
#  ('refectory', 'refectories'),
#  ('newsman', 'newsmen'),
#  ('illnes', 'illness'),
#  ('rune', 'runes'),
#  ('institution', 'institutions'),
#  ('37-degree', '37-degrees'),
#  ('bu', 'bus'),
#  ('fascicle', 'fascicles'),
#  ('inclusivenes', 'inclusiveness'),
#  ('impurity', 'impurities'),
#  ('mummy', 'mummies'),
#  ('electronic', 'electronics'),
#  ('dolore', 'dolores'),
#  ('bang-sash', 'bang-sashes'),
#  ('egg', 'eggs'),
#  ('hurray', 'hurrays'),
#  ('annapoli', 'annapolis'),
#  ('tregnum', 'tregnums'),
#  ('module', 'modules'),
#  ('three-fourth', 'three-fourths'),
#  ('ramilly', 'ramillies'),
#  ('censor', 'censors'),
#  ('bogeyman', 'bogeymen'),
#  ('rocket', 'rockets'),
#  ('revelling', 'revellings'),
#  ('feature', 'features'),
#  ('hercule', 'hercules'),
#  ('patrones', 'patroness'),
#  ('headstone', 'headstones'),
#  ('politic', 'politics'),
#  ('sauterne', 'sauternes'),
#  ('snowflake', 'snowflakes'),
#  ('oldster', 'oldsters'),
#  ('guifte', 'guiftes'),
#  ('expenditure', 'expenditures'),
#  ('biddy', 'biddies'),
#  ('clannishnes', 'clannishness'),
#  ('transformer', 'transformers'),
#  ('creeper', 'creepers'),
#  ('davi', 'davis'),
#  ('extraneousnes', 'extraneousness'),
#  ('polyelectrolyte', 'polyelectrolytes'),
#  ('grassland', 'grasslands'),
#  ('tara', 'taras'),
#  ('tawe', 'tawes'),
#  ('win', 'wins'),
#  ('hydride', 'hydrides'),
#  ('rut', 'ruts'),
#  ('share-holder', 'share-holders'),
#  ('cuirassier', 'cuirassiers'),
#  ('samenes', 'sameness'),
#  ('caption', 'captions'),
#  ('remission', 'remissions'),
#  ('downer', 'downers'),
#  ('gregoriu', 'gregorius'),
#  ('tumefacien', 'tumefaciens'),
#  ('jew-hater', 'jew-haters'),
#  ('dullnes', 'dullness'),
#  ('serviette', 'serviettes'),
#  ('slav', 'slavs'),
#  ('mercede', 'mercedes'),
#  ('philantropist', 'philantropists'),
#  ('forefather', 'forefathers'),
#  ('hos', 'hoss'),
#  ('alveolu', 'alveolus'),
#  ('work-succes', 'work-success'),
#  ('spouse', 'spouses'),
#  ('concession', 'concessions'),
#  ('ami', 'amis'),
#  ('medic', 'medics'),
#  ('spacer', 'spacers'),
#  ('knighte', 'knightes'),
#  ('carbone', 'carbones'),
#  ('alien', 'aliens'),
#  ('meannes', 'meanness'),
#  ('prosody', 'prosodies'),
#  ('scripture', 'scriptures'),
#  ('worthlessnes', 'worthlessness'),
#  ('suces', 'sucess'),
#  ('pon', 'pons'),
#  ('-20-degree', '-20-degrees'),
#  ('hazelnut', 'hazelnuts'),
#  ('mailbox', 'mailboxes'),
#  ('triando', 'triandos'),
#  ('False-general', 'secretary-general'),
#  ('bevel', 'bevels'),
#  ('a-bomb', 'a-bombs'),
#  ('axiom', 'axioms'),
#  ('macisaac', 'macisaacs'),
#  ('hyacinth', 'hyacinths'),
#  ('contemporary', 'contemporaries'),
#  ('halide', 'halides'),
#  ('blackfoot', 'blackfeet'),
#  ("'40'", "'40's"),
#  ('merchant', 'merchants'),
#  ('startup', 'startups'),
#  ('simple', 'simples'),
#  ('cervante', 'cervantes'),
#  ('hardwood', 'hardwoods'),
#  ('sizovum', 'sizova'),
#  ('childishnes', 'childishness'),
#  ('jes', 'jess'),
#  ('romancer', 'romancers'),
#  ('necessary', 'necessaries'),
#  ('cretaceou', 'cretaceous'),
#  ('berg', 'bergs'),
#  ('pop', 'pops'),
#  ('propagandist', 'propagandists'),
#  ("1920'", "1920's"),
#  ('lifter', 'lifters'),
#  ('necrosi', 'necrosis'),
#  ('jenkin', 'jenkins'),
#  ('fiercenes', 'fierceness'),
#  ('byproduct', 'byproducts'),
#  ('pre-condition', 'pre-conditions'),
#  ('thermostatic', 'thermostatics'),
#  ('flourish', 'flourishes'),
#  ('californian', 'californians'),
#  ('arsine', 'arsines'),
#  ('ozark', 'ozarks'),
#  ('mennonite', 'mennonites'),
#  ('son-of-a bitch', 'son-of-a-bitch'),
#  ('redaction', 'redactions'),
#  ('truthfulnes', 'truthfulness'),
#  ('saddlebag', 'saddlebags'),
#  ('incendiary', 'incendiaries'),
#  ('insect', 'insects'),
#  ('motorist', 'motorists'),
#  ('make', 'makes'),
#  ('slipper', 'slippers'),
#  ('elector', 'electors'),
#  ('bruise', 'bruises'),
#  ('pathway', 'pathways'),
#  ('gyrocompas', 'gyrocompass'),
#  ('working-clas', 'working-class'),
#  ('starling', 'starlings'),
#  ('abys', 'abyss'),
#  ('waitres', 'waitress'),
#  ('federal', 'federals'),
#  ('glider', 'gliders'),
#  ('viciousnes', 'viciousness'),
#  ('citizen', 'citizens'),
#  ('circumscription', 'circumscriptions'),
#  ('apach', 'apaches'),
#  ('limit', 'limits'),
#  ('sud', 'suds'),
#  ('pupil', 'pupils'),
#  ('abdoman', 'abdomen'),
#  ('reye', 'reyes'),
#  ('kickback', 'kickbacks'),
#  ('gustavu', 'gustavus'),
#  ('two', 'twos'),
#  ('cheerfulnes', 'cheerfulness'),
#  ('calorie', 'calories'),
#  ('los', 'loss'),
#  ('jewishnes', 'jewishness'),
#  ('disclosure', 'disclosures'),
#  ('cub', 'cubs'),
#  ('collaborator', 'collaborators'),
#  ('rosary', 'rosaries'),
#  ('slovenlines', 'slovenliness'),
#  ('pandanu', 'pandanus'),
#  ('landowner', 'landowners'),
#  ('duches', 'duchess'),
#  ('moral', 'morals'),
#  ('mana', 'manas'),
#  ('contrib', 'contribs'),
#  ('youngster', 'youngsters'),
#  ('cracker', 'crackers'),
#  ('underclothe', 'underclothes'),
#  ('auxiliary', 'auxiliaries'),
#  ('fingertip', 'fingertips'),
#  ('antinomian', 'antinomians'),
#  ('comrade', 'comrades'),
#  ('proto-yokut', 'proto-yokuts'),
#  ("kid'", "kid's"),
#  ('sweepstake', 'sweepstakes'),
#  ('porpoise', 'porpoises'),
#  ('8-ball', '8-balls'),
#  ('superlative', 'superlatives'),
#  ('spice', 'spices'),
#  ('up', 'ups'),
#  ('gadget', 'gadgets'),
#  ('loui', 'louis'),
#  ('encomium', 'encomiums'),
#  ('kenning', 'kennings'),
#  ('bandoleer', 'bandoleers'),
#  ('typhu', 'typhus'),
#  ('outcrop', 'outcrops'),
#  ('gobbler', 'gobblers'),
#  ('underwriter', 'underwriters'),
#  ('bauhau', 'bauhaus'),
#  ('peco', 'pecos'),
#  ('curie-weis', 'curie-weiss'),
#  ('mephistophele', 'mephistopheles'),
#  ('unwillingnes', 'unwillingness'),
#  ('businessman', 'businessmen'),
#  ('lawles', 'lawless'),
#  ('columbine', 'columbines'),
#  ('fungu', 'fungus'),
#  ("level'", "level's"),
#  ('expressivenes', 'expressiveness'),
#  ('fen', 'fens'),
#  ('canva', 'canvas'),
#  ('massachusett', 'massachusetts'),
#  ('blitze', 'blitzes'),
#  ('theoretician', 'theoreticians'),
#  ('apergillu', 'apergillus'),
#  ('waterway', 'waterways'),
#  ('semirami', 'semiramis'),
#  ('bitter', 'bitters'),
#  ('phylli', 'phyllis'),
#  ('lackey', 'lackeys'),
#  ('installation', 'installations'),
#  ('lobe', 'lobes'),
#  ('sulk', 'sulks'),
#  ('barbudo', 'barbudos'),
#  ('speciman', 'specimen'),
#  ("r'", "r's"),
#  ('aggressivenes', 'aggressiveness'),
#  ('pulling', 'pullings'),
#  ('mr', 'mrs'),
#  ('ximenez-varga', 'ximenez-vargas'),
#  ("myra'", "myra's"),
#  ('by-road', 'by-roads'),
#  ('minu', 'minus'),
#  ('firework', 'fireworks'),
#  ('gunfight', 'gunfights'),
#  ('opiate', 'opiates'),
#  ('powerfulnes', 'powerfulness'),
#  ("baseball'", "baseball's"),
#  ('dynamic', 'dynamics'),
#  ('politician', 'politicians'),
#  ("knife'", "knife's"),
#  ('eyelash', 'eyelashes'),
#  ('anglo-american', 'anglo-americans'),
#  ('conceit', 'conceits'),
#  ('eclipse', 'eclipses'),
#  ('mattress', 'mattresses'),
#  ('contingency', 'contingencies'),
#  ('moo', 'moos'),
#  ('jacque', 'jacques'),
#  ('servatiu', 'servatius'),
#  ('greatnes', 'greatness'),
#  ('offensive', 'offensives'),
#  ('libertarian', 'libertarians'),
#  ('worry', 'worries'),
#  ('peppermint', 'peppermints'),
#  ('repulsion', 'repulsions'),
#  ('woodcutter', 'woodcutters'),
#  ('wrestle', 'wrestles'),
#  ('cavallini', 'cavallinis'),
#  ('lubberlander', 'lubberlanders'),
#  ('lung', 'lungs'),
#  ('stockynge', 'stockynges'),
#  ('no', 'noes'),
#  ('hotdog', 'hotdogs'),
#  ('nikolai', 'nikolais'),
#  ('underhandednes', 'underhandedness'),
#  ('epithet', 'epithets'),
#  ('cog', 'cogs'),
#  ('tough', 'toughs'),
#  ('australite', 'australites'),
#  ('saracen', 'saracens'),
#  ('cleaner', 'cleaners'),
#  ('indefinitenes', 'indefiniteness'),
#  ('asset', 'assets'),
#  ('bursiti', 'bursitis'),
#  ('pickin', 'pickins'),
#  ('brave', 'braves'),
#  ('sipper', 'sippers'),
#  ("1800'", "1800's"),
#  ('piman', 'pimen'),
#  ("kate'", "kate's"),
#  ('pride-venu', 'pride-venus'),
#  ('paul-minneapoli', 'paul-minneapolis'),
#  ('bikini', 'bikinis'),
#  ('tragedian', 'tragedians'),
#  ('shoe', 'shoes'),
#  ('perforation', 'perforations'),
#  ('lexicostatistic', 'lexicostatistics'),
#  ('chattel', 'chattels'),
#  ('teen-ager', 'teen-agers'),
#  ('mon-goddes', 'mon-goddess'),
#  ('huskines', 'huskiness'),
#  ('nutrient', 'nutrients'),
#  ('adapter', 'adapters'),
#  ('guideline', 'guidelines'),
#  ('catharsi', 'catharsis'),
#  ('worshipper', 'worshippers'),
#  ('tsitouri', 'tsitouris'),
#  ('coomb', 'coombs'),
#  ('caiu', 'caius'),
#  ("725'", "725's"),
#  ('crossroad', 'crossroads'),
#  ('spigot', 'spigots'),
#  ('low-pas', 'low-pass'),
#  ('potion', 'potions'),
#  ('chrysanthemum', 'chrysanthemums'),
#  ('orchid', 'orchids'),
#  ('sucker', 'suckers'),
#  ('adio', 'adios'),
#  ('fortres', 'fortress'),
#  ('trait', 'traits'),
#  ('stasi', 'stasis'),
#  ("chip-o'", "chip-o's"),
#  ('bonu', 'bonus'),
#  ('maneuver', 'maneuvers'),
#  ('photo', 'photos'),
#  ('kinesic', 'kinesics'),
#  ('ovum', 'ova'),
#  ("camera'", "camera's"),
#  ('preserve', 'preserves'),
#  ('mendere', 'menderes'),
#  ('forty-niner', 'forty-niners'),
#  ('elio', 'elios'),
#  ('nicodemu', 'nicodemus'),
#  ('pudding', 'puddings'),
#  ('caseworker', 'caseworkers'),
#  ('sinuousnes', 'sinuousness'),
#  ('crackpot', 'crackpots'),
#  ('predecessor', 'predecessors'),
#  ('marquee', 'marquees'),
#  ('moccasin', 'moccasins'),
#  ('politenes', 'politeness'),
#  ('clearnes', 'clearness'),
#  ('eyelet', 'eyelets'),
#  ("btu'", "btu's"),
#  ('bicep', 'biceps'),
#  ('cameraman', 'cameramen'),
#  ('anarchist-adventurer', 'anarchist-adventurers'),
#  ('ethiopian', 'ethiopians'),
#  ('colour-print', 'colour-prints'),
#  ('fellow-employee', 'fellow-employees'),
#  ('thousandth', 'thousandths'),
#  ('ecumenicist', 'ecumenicists'),
#  ('180-degree', '180-degrees'),
#  ('twin', 'twins'),
#  ('ree', 'rees'),
#  ('inhumanity', 'inhumanities'),
#  ('gagwriter', 'gagwriters'),
#  ('grigors', 'grigorss'),
#  ('volkswagen', 'volkswagens'),
#  ('jew', 'jews'),
#  ('calculator', 'calculators'),
#  ('confuciu', 'confucius'),
#  ('fund', 'funds'),
#  ('adelo', 'adelos'),
#  ('patissery', 'patisseries'),
#  ('lis', 'liss'),
#  ('duma', 'dumas'),
#  ('folksong', 'folksongs'),
#  ('minute', 'minutes'),
#  ('jule', 'jules'),
#  ('brashnes', 'brashness'),
#  ('gurkha', 'gurkhas'),
#  ('diplomat', 'diplomats'),
#  ('primer', 'primers'),
#  ('gunner', 'gunners'),
#  ('mid-thirty', 'mid-thirties'),
#  ('atheist', 'atheists'),
#  ('fingernail', 'fingernails'),
#  ('cudgel', 'cudgels'),
#  ('injunction', 'injunctions'),
#  ('strap', 'straps'),
#  ('alga', 'algae'),
#  ('technicality', 'technicalities'),
#  ('helpfulnes', 'helpfulness'),
#  ('foible', 'foibles'),
#  ('fullnes', 'fullness'),
#  ('asbesto', 'asbestos'),
#  ('abnormality', 'abnormalities'),
#  ('watershed', 'watersheds'),
#  ('olympic', 'olympics'),
#  ('cutter', 'cutters'),
#  ('athen', 'athens'),
#  ('harelip', 'harelips'),
#  ('sear', 'sears'),
#  ('fracase', 'fracases'),
#  ('southerner', 'southerners'),
#  ('mammal', 'mammals'),
#  ('usi', 'usis'),
#  ('halogen', 'halogens'),
#  ('nautilu', 'nautilus'),
#  ("1940'", "1940's"),
#  ('sethnes', 'sethness'),
#  ('stewardes', 'stewardess'),
#  ('neuriti', 'neuritis'),
#  ('dimension', 'dimensions'),
#  ('simpkin', 'simpkins'),
#  ('cutout', 'cutouts'),
#  ('phosphoru', 'phosphorus'),
#  ('three', 'threes'),
#  ('truss', 'trusses'),
#  ('pectoral', 'pectorals'),
#  ('gauchery', 'gaucheries'),
#  ('badman', 'badmen'),
#  ('seagull', 'seagulls'),
#  ('addres', 'address'),
#  ('besieger', 'besiegers'),
#  ('rheumatic', 'rheumatics'),
#  ('hike', 'hikes'),
#  ('pelt', 'pelts'),
#  ('oystcher', 'oystchers'),
#  ('equalizer', 'equalizers'),
#  ("bastard'", "bastard's"),
#  ('bathyran', 'bathyrans'),
#  ('pea', 'peas'),
#  ('sinfulnes', 'sinfulness'),
#  ('pistoleer', 'pistoleers'),
#  ('custom', 'customs'),
#  ('bate', 'bates'),
#  ('sentimentalist', 'sentimentalists'),
#  ("kitty'", "kitty's"),
#  ('acre-foot', 'acre-feet'),
#  ('circumstance', 'circumstances'),
#  ('thug', 'thugs'),
#  ('inboard', 'inboards'),
#  ('great-niece', 'great-nieces'),
#  ('marking', 'markings'),
#  ('line-fragment', 'line-fragments'),
#  ('argonaut', 'argonauts'),
#  ('ahren', 'ahrens'),
#  ('coworker', 'coworkers'),
#  ('peccadillo', 'peccadilloes'),
#  ('smoothnes', 'smoothness'),
#  ('orlean', 'orleans'),
#  ('drunkennes', 'drunkenness'),
#  ('co-worker', 'co-workers'),
#  ('coarsenes', 'coarseness'),
#  ('yonker', 'yonkers'),
#  ('jonquil', 'jonquils'),
#  ('smelt', 'smelts'),
#  ('vampire', 'vampires'),
#  ('raincoat', 'raincoats'),
#  ('leading', 'leadings'),
#  ('fondnes', 'fondness'),
#  ('modern', 'moderns'),
#  ('nightdres', 'nightdress'),
#  ('bird', 'birds'),
#  ('intimation', 'intimations'),
#  ('uselessnes', 'uselessness'),
#  ('earphone', 'earphones'),
#  ('beste', 'bestes'),
#  ('caryatide', 'caryatides'),
#  ('cavalryman', 'cavalrymen'),
#  ('mcrobert', 'mcroberts'),
#  ('symond', 'symonds'),
#  ('argo', 'argos'),
#  ('arapaci', 'arapacis'),
#  ('node', 'nodes'),
#  ('instalment', 'instalments'),
#  ('allowance', 'allowances'),
#  ('whitenes', 'whiteness'),
#  ("money'", "money's"),
#  ('althau', 'althaus'),
#  ('guidepost', 'guideposts'),
#  ('creature', 'creatures'),
#  ('pheasant', 'pheasants'),
#  ('grotto', 'grottoes'),
#  ('drape', 'drapes'),
#  ('ore', 'ores'),
#  ('tribesman', 'tribesmen'),
#  ('eade', 'eades'),
#  ('vagary', 'vagaries'),
#  ('downstair', 'downstairs'),
#  ('confederate', 'confederates'),
#  ('antipode', 'antipodes'),
#  ('goddes', 'goddess'),
#  ('ebbett', 'ebbetts'),
#  ('favorite', 'favorites'),
#  ('desegregation-from-court order', 'desegregation-from-court-order'),
#  ('booklist', 'booklists'),
#  ('monopolist', 'monopolists'),
#  ('persuader', 'persuaders'),
#  ('selkirker', 'selkirkers'),
#  ('autocrat', 'autocrats'),
#  ('colleague', 'colleagues'),
#  ('narcotic', 'narcotics'),
#  ("penny'", "penny's"),
#  ('non-christian', 'non-christians'),
#  ('subfigure', 'subfigures'),
#  ('dropping', 'droppings'),
#  ('contestant', 'contestants'),
#  ('abdomini', 'abdominis'),
#  ('dune', 'dunes'),
#  ('addict', 'addicts'),
#  ('commercial', 'commercials'),
#  ("aec'", "aec's"),
#  ('poem', 'poems'),
#  ('hes', 'hess'),
#  ('110-degree', '110-degrees'),
#  ('salesman', 'salesmen'),
#  ('gradation', 'gradations'),
#  ('bribe', 'bribes'),
#  ('ear-muff', 'ear-muffs'),
#  ('pil', 'pils'),
#  ('parolee', 'parolees'),
#  ('packer', 'packers'),
#  ('foot', 'feet'),
#  ('shifter', 'shifters'),
#  ('weaknes', 'weakness'),
#  ('likenes', 'likeness'),
#  ('commune', 'communes'),
#  ('asterisk', 'asterisks'),
#  ('ear', 'ears'),
#  ('gospeler', 'gospelers'),
#  ("katharine'", "katharine's"),
#  ('stubbornnes', 'stubbornness'),
#  ('aspiration', 'aspirations'),
#  ('kamen', 'kamens'),
#  ('forte-piano', 'forte-pianos'),
#  ('alumnus', 'alumni'),
#  ('cutlas', 'cutlass'),
#  ('hulk', 'hulks'),
#  ('surplu', 'surplus'),
#  ('ox', 'oxen'),
#  ('homeowner', 'homeowners'),
#  ('congregationalist', 'congregationalists'),
#  ('meteorite', 'meteorites'),
#  ('jap', 'japs'),
#  ('theoritician', 'theoriticians'),
#  ('swelling', 'swellings'),
#  ('slynes', 'slyness'),
#  ("kind'", "kind's"),
#  ('', 's'),
#  ("arlene'", "arlene's"),
#  ('convulsion', 'convulsions'),
#  ('rapist', 'rapists'),
#  ('integral', 'integrals'),
#  ('alienu', 'alienus'),
#  ('holines', 'holiness'),
#  ('applique', 'appliques'),
#  ('paring', 'parings'),
#  ('expansivenes', 'expansiveness'),
#  ('microanalysi', 'microanalysis'),
#  ('estuary', 'estuaries'),
#  ('well-spring', 'well-springs'),
#  ('fellow-man', 'fellow-men'),
#  ('implement', 'implements'),
#  ('ribe', 'ribes'),
#  ('berkshire', 'berkshires'),
#  ("mid-1960'", "mid-1960's"),
#  ('liquid-glas', 'liquid-glass'),
#  ('ballgown', 'ballgowns'),
#  ('funeral-accessory', 'funeral-accessories'),
#  ('canadian', 'canadians'),
#  ('happening', 'happenings'),
#  ('lamentation', 'lamentations'),
#  ('docter', 'docters'),
#  ('eye', 'eyes'),
#  ('devotee', 'devotees'),
#  ('eater', 'eaters'),
#  ('clement', 'clements'),
#  ('justnes', 'justness'),
#  ('byza', 'byzas'),
#  ('potentiality', 'potentialities'),
#  ('thriller', 'thrillers'),
#  ('tadpole', 'tadpoles'),
#  ('overtone', 'overtones'),
#  ('epicycle', 'epicycles'),
#  ('dipole', 'dipoles'),
#  ('northener', 'northeners'),
#  ('highnes', 'highness'),
#  ('free-holder', 'free-holders'),
#  ('flame', 'flames'),
#  ('whorl', 'whorls'),
#  ('rating', 'ratings'),
#  ('hero-worshipper', 'hero-worshippers'),
#  ('miner', 'miners'),
#  ('tablecloth', 'tablecloths'),
#  ('hydraulic', 'hydraulics'),
#  ('headquarter', 'headquarters'),
#  ('bloodstain', 'bloodstains'),
#  ('nigra', 'nigras'),
#  ('10-degree', '10-degrees'),
#  ('rhinestone', 'rhinestones'),
#  ('goody', 'goodies'),
#  ('saunder', 'saunders'),
#  ('moderate', 'moderates'),
#  ('candidate', 'candidates'),
#  ('irregular', 'irregulars'),
#  ('somersault', 'somersaults'),
#  ('athenian', 'athenians'),
#  ('soothsayer', 'soothsayers'),
#  ('slave-laborer', 'slave-laborers'),
#  ('gymnastic', 'gymnastics'),
#  ('timer', 'timers'),
#  ('thesauru', 'thesaurus'),
#  ('call-back', 'call-backs'),
#  ('contrabas', 'contrabass'),
#  ('ghoul', 'ghouls'),
#  ('shaker', 'shakers'),
#  ('cros', 'cross'),
#  ('shingle', 'shingles'),
#  ('sale', 'sales'),
#  ('siren', 'sirens'),
#  ('hypnosi', 'hypnosis'),
#  ('buttock', 'buttocks'),
#  ('flower', 'flowers'),
#  ('internationalist', 'internationalists'),
#  ('muslim', 'muslims'),
#  ('macgregor', 'macgregors'),
#  ('officeholder', 'officeholders'),
#  ('peer', 'peers'),
#  ('dormitory', 'dormitories'),
#  ('etho', 'ethos'),
#  ('legging', 'leggings'),
#  ('thicket', 'thickets'),
#  ('himalaya', 'himalayas'),
#  ('joblessnes', 'joblessness'),
#  ('deadhead', 'deadheads'),
#  ('interval', 'intervals'),
#  ('jack-an-ape', 'jack-an-apes'),
#  ('listener', 'listeners'),
#  ('egyptian', 'egyptians'),
#  ('willing', 'willings'),
#  ('catecholamine', 'catecholamines'),
#  ('skopa', 'skopas'),
#  ('victual', 'victuals'),
#  ('oasis', 'oases'),
#  ('buckaroo', 'buckaroos'),
#  ("1890'", "1890's"),
#  ('azalea', 'azaleas'),
#  ('error', 'errors'),
#  ('awning', 'awnings'),
#  ('heavines', 'heaviness'),
#  ('atla', 'atlas'),
#  ('metamorphosi', 'metamorphosis'),
#  ('mill', 'mills'),
#  ('silhouette', 'silhouettes'),
#  ('cop', 'cops'),
#  ('parliamentarian', 'parliamentarians'),
#  ('romantic', 'romantics'),
#  ('swimmer', 'swimmers'),
#  ('upperclassman', 'upperclassmen'),
#  ('enni', 'ennis'),
#  ('worker', 'workers'),
#  ('heavy-electrical-good', 'heavy-electrical-goods'),
#  ('invader', 'invaders'),
#  ('sabra', 'sabras'),
#  ('hesperu', 'hesperus'),
#  ('housebreaker', 'housebreakers'),
#  ('acrobatic', 'acrobatics'),
#  ('one', 'ones'),
#  ('highlight', 'highlights'),
#  ('regent', 'regents'),
#  ('horseman', 'horsemen'),
#  ('massif', 'massifs'),
#  ('soddy', 'soddies'),
#  ('beneficiary', 'beneficiaries'),
#  ('sausage', 'sausages'),
#  ('olerich', 'olerichs'),
#  ('rocky', 'rockies'),
#  ('lassu', 'lassus'),
#  ('prop', 'props'),
#  ('contributor', 'contributors'),
#  ('contour', 'contours'),
#  ('fp', 'fps'),
#  ('acorn', 'acorns'),
#  ('davit', 'davits'),
#  ('ringsider', 'ringsiders'),
#  ('saint-saen', 'saint-saens'),
#  ('seyne', 'seynes'),
#  ('performer', 'performers'),
#  ('mena', 'menas'),
#  ('eagernes', 'eagerness'),
#  ('paddy', 'paddies'),
#  ('dollars-and-cent', 'dollars-and-cents'),
#  ('lay-sister', 'lay-sisters'),
#  ('airman', 'airmen'),
#  ('sea-horse', 'sea-horses'),
#  ('copybook', 'copybooks'),
#  ('heretic', 'heretics'),
#  ('alderman', 'aldermen'),
#  ('hollownes', 'hollowness'),
#  ('mussel', 'mussels'),
#  ('elvi', 'elvis'),
#  ('cross-purpose', 'cross-purposes'),
#  ('leach', 'leaches'),
#  ('european', 'europeans'),
#  ('gear-set', 'gear-sets'),
#  ('juda', 'judas'),
#  ('camellia', 'camellias'),
#  ("throat'", "throat's"),
#  ('mitropoulo', 'mitropoulos'),
#  ('wonderfulnes', 'wonderfulness'),
#  ('affiliation', 'affiliations'),
#  ('hutchin', 'hutchins'),
#  ('skull-bashing', 'skull-bashings'),
#  ('term', 'terms'),
#  ('earthman', 'earthmen'),
#  ('subsystem', 'subsystems'),
#  ('martian', 'martians'),
#  ("b-52'", "b-52's"),
#  ('tes', 'tess'),
#  ('crystallite', 'crystallites'),
#  ('flyway', 'flyways'),
#  ('american', 'americans'),
#  ('1930', '1930s'),
#  ('ring-around-the rosie', 'ring-around-the-rosie'),
#  ('non-conformist', 'non-conformists'),
#  ('catkin', 'catkins'),
#  ('map', 'maps'),
#  ('enclave', 'enclaves'),
#  ('propertiu', 'propertius'),
#  ('sex-manual', 'sex-manuals'),
#  ('sawnder', 'sawnders'),
#  ('follower', 'followers'),
#  ('suffragette', 'suffragettes'),
#  ('cross-striation', 'cross-striations'),
#  ('picture-image', 'picture-images'),
#  ('fawke', 'fawkes'),
#  ('sweeping', 'sweepings'),
#  ('zionist', 'zionists'),
#  ('silkworm', 'silkworms'),
#  ('in-migrant', 'in-migrants'),
#  ('social-clas', 'social-class'),
#  ('aeronautic', 'aeronautics'),
#  ('item', 'items'),
#  ('valve', 'valves'),
#  ('uglines', 'ugliness'),
#  ("sba'", "sba's"),
#  ('reading-room', 'reading-rooms'),
#  ('bull-session', 'bull-sessions'),
#  ('120-degree', '120-degrees'),
#  ('paw', 'paws'),
#  ('monosyllable', 'monosyllables'),
#  ('fire-cracker', 'fire-crackers'),
#  ('rhinotracheiti', 'rhinotracheitis'),
#  ('lat', 'lats'),
#  ('passivenes', 'passiveness'),
#  ('physic', 'physics'),
#  ('teenager', 'teenagers'),
#  ('ideal', 'ideals'),
#  ('inch', 'inches'),
#  ('diaper', 'diapers'),
#  ('mandamu', 'mandamus'),
#  ('abberation', 'abberations'),
#  ('bloodhound', 'bloodhounds'),
#  ('determinant', 'determinants'),
#  ('aeschylu', 'aeschylus'),
#  ('wiener', 'wieners'),
#  ('panta', 'pantas'),
#  ('blue-eye', 'blue-eyes'),
#  ('voucher', 'vouchers'),
#  ('scripp', 'scripps'),
#  ('intellectual', 'intellectuals'),
#  ('trustee', 'trustees'),
#  ('hessian', 'hessians'),
#  ('lapel', 'lapels'),
#  ('panyoti', 'panyotis'),
#  ('richnes', 'richness'),
#  ('lohman', 'lohmans'),
#  ('cloddishnes', 'cloddishness'),
#  ('upland', 'uplands'),
#  ('orchesi', 'orchesis'),
#  ('gu', 'gus'),
#  ('copyright', 'copyrights'),
#  ('casanovum', 'casanova'),
#  ('gilli', 'gillis'),
#  ('stirup', 'stirups'),
#  ('cassiu', 'cassius'),
#  ('mitten', 'mittens'),
#  ('brazo', 'brazos'),
#  ('misdirector', 'misdirectors'),
#  ('pundit', 'pundits'),
#  ('plowshare', 'plowshares'),
#  ('malenes', 'maleness'),
#  ('annal', 'annals'),
#  ('chorine', 'chorines'),
#  ('rib', 'ribs'),
#  ('sadnes', 'sadness'),
#  ('cyst', 'cysts'),
#  ('twenty', 'twenties'),
#  ('sampler', 'samplers'),
#  ('hemlock', 'hemlocks'),
#  ('transfusion', 'transfusions'),
#  ('life-contract', 'life-contracts'),
#  ('albican', 'albicans'),
#  ('deftnes', 'deftness'),
#  ('implication', 'implications'),
#  ('inductee', 'inductees'),
#  ('work-paralysi', 'work-paralysis'),
#  ('cleanup', 'cleanups'),
#  ('fantod', 'fantods'),
#  ('sidechair', 'sidechairs'),
#  ('aloofnes', 'aloofness'),
#  ('robber', 'robbers'),
#  ('singer', 'singers'),
#  ('programme', 'programmes'),
#  ('pajama', 'pajamas'),
#  ('fin', 'fins'),
#  ('sidearm', 'sidearms'),
#  ('supermarket', 'supermarkets'),
#  ('balsam', 'balsams'),
#  ('console', 'consoles'),
#  ('weed', 'weeds'),
#  ('firebreak', 'firebreaks'),
#  ('tentacle', 'tentacles'),
#  ('potlatch', 'potlatches'),
#  ('tit', 'tits'),
#  ('billboard', 'billboards'),
#  ('bigot', 'bigots'),
#  ('histrionic', 'histrionics'),
#  ('corneilu', 'corneilus'),
#  ('victorian', 'victorians'),
#  ('man-of-war', 'men-of-war'),
#  ('solid', 'solids'),
#  ...}

# %%
# question b
tagged = [(w.lower(), tag) for (w, tag) in brown.tagged_words() if w.isalpha()]
tagged_words = {}
for (w, tag) in tagged:
    if w not in tagged_words.keys():
        tagged_words[w] = [tag]
    else:
        if tag not in tagged_words[w]:
            tagged_words[w].append(tag)

# %%
max_word = []
max_tags = 0
for w in tagged_words.keys():
    if len(tagged_words[w]) > max_tags:
        max_tags = len(tagged_words[w])
        max_word = [w]
    elif len(tagged_words[w]) == max_tags:
        max_word.append(w)

# %%
max_word
# Out:
# ['that']

# %%
max_tags
# Out:
# 15

# %%
print ('The tags are: ', tagged_words[max_word[0]])
# Out:
# The tags are:  ['CS', 'WPS', 'DT', 'QL', 'WPO', 'CS-HL', 'DT-TL', 'WPS-TL', 'DT-HL', 'DT-NC', 'NIL', 'WPS-NC', 'WPO-NC', 'CS-NC', 'WPS-HL']

# %%
tags = [tag for (w, tag) in brown.tagged_words()]

# %%
fq_tags = nltk.FreqDist(tags)

# %%
fq_tags.most_common(20)
# Out:
# [('NN', 152470),
#  ('IN', 120557),
#  ('AT', 97959),
#  ('JJ', 64028),
#  ('.', 60638),
#  (',', 58156),
#  ('NNS', 55110),
#  ('CC', 37718),
#  ('RB', 36464),
#  ('NP', 34476),
#  ('VB', 33693),
#  ('VBN', 29186),
#  ('VBD', 26167),
#  ('CS', 22143),
#  ('PPS', 18253),
#  ('VBG', 17893),
#  ('PP$', 16872),
#  ('TO', 14918),
#  ('PPSS', 13802),
#  ('CD', 13510)]

# %%
backward_tags = list(reversed(tags))

# %%
for i in range (0, len(backward_tags)):
    if (backward_tags[i].startswith('NN') or tag.startswith('NNS') or tag.startswith('NP') or tag.startswith('NPS')):
        backward_tags[i] = 'NOUN'

# %%
backward_fq = nltk.ConditionalFreqDist(list(nltk.bigrams(backward_tags)))

# %%
backward_fq['NOUN'].most_common(20)
# Out:
# [('AT', 59656),
#  ('JJ', 40864),
#  ('IN', 24012),
#  ('NOUN', 23702),
#  ('PP$', 12241),
#  ('CC', 6610),
#  ('CD', 5264),
#  ('AP', 5112),
#  ('DT', 4540),
#  ('VBG', 4407),
#  (',', 3973),
#  ('VBN', 3638),
#  ('.', 3160),
#  ('JJ-TL', 2595),
#  ('VB', 2432),
#  ('NP', 2013),
#  ('NP-TL', 1877),
#  ('CS', 1745),
#  ('NP$', 1654),
#  ('DTI', 1557)]

# %%
from nltk.corpus import movie_reviews

# %%
documents = [(list(movie_reviews.words(fileid)), category)
              for category in movie_reviews.categories()
                 for fileid in movie_reviews.fileids(category)]

# %%
import random
random.shuffle(documents)

# %%
from nltk.corpus import wordnet as wn
all_words = nltk.FreqDist(w.lower() for w in movie_reviews.words())
word_features = [word for word in list(all_words)[:2000]]

# %%
from nltk.corpus import wordnet as wn
def document_features(document): 
    document_words = set(document) 
    features = {}
    for word in word_features:
        boolean = False
        synsets = wn.synsets(word)
        if len(synsets) == 0:
            features['contains({})'.format(word)] = (word in document_words)
        else:
            for synset in synsets:
                for lemma in synset.lemma_names():
                    if lemma in document_words:
                        boolean = True
                        break
                if boolean == True:
                    break
            features['contains({})'.format(word)] = (boolean)
    '''
    for word in word_features:
        features['contains({})'.format(word)] = (word in document_words)
    '''
    return features
#accuracy1: 0.8, 0.84, 0.75, 0.8, 0.87, 0.76
#accuracy2: 0.8, 0.79, 0.81, 0.82, 0.83, 0.83,

# %%
featuresets = [(document_features(d), c) for (d,c) in documents]
train_set, test_set = featuresets[100:], featuresets[:100]
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.76

# %%
classifier.show_most_informative_features(5)
# Out:
# Most Informative Features
#     contains(schumacher) = True              neg : pos    =     12.3 : 1.0
#           contains(mena) = True              neg : pos    =      5.7 : 1.0
#         contains(suvari) = True              neg : pos    =      5.7 : 1.0
#        contains(bronson) = True              neg : pos    =      5.7 : 1.0
#            contains(ugh) = True              neg : pos    =      5.4 : 1.0
