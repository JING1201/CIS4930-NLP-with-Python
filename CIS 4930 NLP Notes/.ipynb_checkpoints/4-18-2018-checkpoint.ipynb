# %% [markdown]
# Sentence Raw -> Segmentation -> (List of Strings) -> Tokenization -> List of list of strings -> POS Tagging -> List of tuples - > Entity Recognition -> Chunked Sentences (Tuples) -> Relations Recognition

# %%
import nltk

# %%
import re

# %%
def process (text):
    sentences = nltk.sent_tokenize(text)
    sentences = [nltk.word_tokenize(sentence) for sentence in sentences]
    sentences = [nltk.pos_tag(sentence) for sentence in sentences]
    return sentences

# %%
expression = "NP: {<DT>?<JJ>*<NN>}"
chunker = nltk.RegexpParser(expression)

# %%
import os
fid = open('AngelasAshes.txt','r')
data = fid.read()

# %%
sentences = process(data)
sentences
# Out:
# [[('An', 'DT'),
#   ('Excerpt', 'NN'),
#   ('from', 'IN'),
#   ('Angela', 'NNP'),
#   ("'s", 'POS'),
#   ('Ashes', 'NNP'),
#   ('by', 'IN'),
#   ('Frank', 'NNP'),
#   ('McCourt', 'NNP'),
#   (',', ','),
#   ('Chapter', 'NNP'),
#   ('6', 'CD'),
#   (',', ','),
#   ('pages', 'NNS'),
#   ('151', 'CD'),
#   ('-', ':'),
#   ('152', 'CD'),
#   ('Mr.', 'NNP'),
#   ("O'Neill", 'NNP'),
#   ('is', 'VBZ'),
#   ('the', 'DT'),
#   ('master', 'NN'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('fourth', 'JJ'),
#   ('class', 'NN'),
#   ('at', 'IN'),
#   ('the', 'DT'),
#   ('school', 'NN'),
#   ('.', '.')],
#  [('We', 'PRP'),
#   ('call', 'VBP'),
#   ('him', 'PRP'),
#   ('Dotty', 'NNP'),
#   ('because', 'IN'),
#   ('he', 'PRP'),
#   ("'s", 'VBZ'),
#   ('small', 'JJ'),
#   ('like', 'IN'),
#   ('a', 'DT'),
#   ('dot', 'NN'),
#   ('.', '.')],
#  [('He', 'PRP'),
#   ('teaches', 'VBZ'),
#   ('in', 'IN'),
#   ('the', 'DT'),
#   ('one', 'CD'),
#   ('classroom', 'NN'),
#   ('with', 'IN'),
#   ('a', 'DT'),
# ...

# %%
sentences[0]
# Out:
# [('An', 'DT'),
#  ('Excerpt', 'NN'),
#  ('from', 'IN'),
#  ('Angela', 'NNP'),
#  ("'s", 'POS'),
#  ('Ashes', 'NNP'),
#  ('by', 'IN'),
#  ('Frank', 'NNP'),
#  ('McCourt', 'NNP'),
#  (',', ','),
#  ('Chapter', 'NNP'),
#  ('6', 'CD'),
#  (',', ','),
#  ('pages', 'NNS'),
#  ('151', 'CD'),
#  ('-', ':'),
#  ('152', 'CD'),
#  ('Mr.', 'NNP'),
#  ("O'Neill", 'NNP'),
#  ('is', 'VBZ'),
#  ('the', 'DT'),
#  ('master', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('fourth', 'JJ'),
#  ('class', 'NN'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('school', 'NN'),
#  ('.', '.')]

# %%
results = [chunker.parse(sentence) for sentence in sentences]
results[0]
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# C:\Program Files\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self=<IPython.core.formatters.PNGFormatter object>, obj=Tree('S', [Tree('NP', [('An', 'DT'), ('Excerpt',... [('the', 'DT'), ('school', 'NN')]), ('.', '.')]))
#     309             method = get_real_method(obj, self.print_method)
#     310             if method is not None:
# --> 311                 return method()
# ...

# %%
results[0].draw()

# %%
grammar = r"""
    NP: {<DT|PP\$>?<JJ>*<NN>}
        {<NNP>+}
        """

# %%
chunker = nltk.RegexpParser(grammar)
results = [chunker.parse(sentence) for sentence in sentences]
results[0]
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# C:\Program Files\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self=<IPython.core.formatters.PNGFormatter object>, obj=Tree('S', [Tree('NP', [('An', 'DT'), ('Excerpt',... [('the', 'DT'), ('school', 'NN')]), ('.', '.')]))
#     309             method = get_real_method(obj, self.print_method)
#     310             if method is not None:
# --> 311                 return method()
# ...

# %%
results[0].draw()

# %%
grammar = r"""
    NP: {<DT|PP\$>?<JJ>*<NN>}
        {<NNP>+}
    VP: {<TO><VB>}
    """

# %%
chunker = nltk.RegexpParser(grammar)
results = [chunker.parse(sentence) for sentence in sentences]
results[0]
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# C:\Program Files\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self=<IPython.core.formatters.PNGFormatter object>, obj=Tree('S', [Tree('NP', [('An', 'DT'), ('Excerpt',... [('the', 'DT'), ('school', 'NN')]), ('.', '.')]))
#     309             method = get_real_method(obj, self.print_method)
#     310             if method is not None:
# --> 311                 return method()
# ...

# %%
results[2].draw()

# %% [markdown]
# ## IOB Tagging
# - B - beginning of a phrase (chunk)
# - I - inside of a phrase (chunk)
# - O - outside of a phrase (chunks)
# - ex. George (B-NNP) Washington (I-NNP) Carver (I-NNP)
#
# ## Context Free Grammar (CFG)
# - Production Rules
#     - x -> y
#     - start symbol
#     - non-terminal symbol
#     - terminal symbol

# %%
# %env
# Out:
# {'ALLUSERSPROFILE': 'C:\\ProgramData',
#  'ANDROID_HOME': 'C:\\Users\\lowji\\AppData\\Local\\Android\\sdk',
#  'ANDROID_SDK_ROOT': 'C:\\Users\\lowji\\AppData\\Local\\Android\\sdk',
#  'ANT_ROOT': 'C:\\apache-ant-1.9.7\\bin',
#  'APPDATA': 'C:\\Users\\lowji\\AppData\\Roaming',
#  'ASL.LOG': 'Destination=file',
#  'AV_APPDATA': 'C:\\Users\\lowji\\AppData\\Roaming',
#  'CLICOLOR': '1',
#  'COCOS_CONSOLE_ROOT': 'D:\\Academics\\UF\\DreamTeam\\cocos2d-x\\tools\\cocos2d-console\\bin',
#  'COCOS_TEMPLATES_ROOT': 'D:\\Academics\\UF\\DreamTeam\\cocos2d-x\\templates',
#  'COCOS_X_ROOT': 'D:\\Academics\\UF\\DreamTeam',
#  'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files',
#  'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files',
#  'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files',
#  'COMPUTERNAME': 'JING1201',
#  'COMSPEC': 'C:\\WINDOWS\\system32\\cmd.exe',
#  'FPS_BROWSER_APP_PROFILE_STRING': 'Internet Explorer',
#  'FPS_BROWSER_USER_PROFILE_STRING': 'Default',
# ...

# %%
# %env PATH = 'C:\\Program Files\\Anaconda3\\Library\\bin;C:\\Program Files\\Anaconda3\\Library\\bin;C:\\Program Files\\Anaconda3\\Scripts;C:\\Program Files\\Anaconda3\\Library\\bin;C:\\Program Files\\Microsoft MPI\\Bin\\;C:\\WINDOWS\\system32;C:\\WINDOWS;C:\\WINDOWS\\System32\\Wbem;C:\\WINDOWS\\System32\\WindowsPowerShell\\v1.0\\;C:\\Program Files\\Git\\cmd;C:\\Program Files (x86)\\Common Files\\Adobe\\AGL;C:\\Program Files\\Csound6_x64\\bin;C:\\Program Files (x86)\\GtkSharp\\2.12\\bin;C:\\Program Files\\Microsoft SQL Server\\130\\Tools\\Binn\\;C:\\Python27;C:\\Program Files\\dotnet\\;C:\\Program Files\\Anaconda3;C:\\Program Files\\Anaconda3\\Scripts;C:\\Program Files\\Anaconda3\\Library\\bin;C:\\Program Files\\PuTTY\\;C:\\Program Files\\Java\\jdk1.8.0_131\\jre;C:\\MinGW\\bin;C:\\HashiCorp\\Vagrant\\bin;C:\\Program Files (x86)\\Yarn\\bin;C:\\Program Files\\nodejs\\;D:\\Academics\\UF\\DreamTeam\\cocos2d-x\\templates;D:\\Academics\\UF\\DreamTeam\\cocos2d-x\\tools\\cocos2d-console\\bin;\\cocos2d-x\\templates;C:\\Python27;C:\\Users\\lowji\\AppData\\Local\\GitHubDesktop\\bin;C:\\Users\\lowji\\AppData\\Local\\Yarn\\bin;C:\\Users\\lowji\\AppData\\Roaming\\npm;C:\\Users\\lowji\\AppData\\Local\\Microsoft\\WindowsApps;;C:\\Program Files (x86)\\Microsoft VS Code\\bin;C:\\Program Files\\Anaconda3\\lib\\site-packages\\numpy\\.libs;C:\\Program Files\\gs\\gs9.23\\bin'
# Out:
# env: PATH='C:\\Program Files\\Anaconda3\\Library\\bin;C:\\Program Files\\Anaconda3\\Library\\bin;C:\\Program Files\\Anaconda3\\Scripts;C:\\Program Files\\Anaconda3\\Library\\bin;C:\\Program Files\\Microsoft MPI\\Bin\\;C:\\WINDOWS\\system32;C:\\WINDOWS;C:\\WINDOWS\\System32\\Wbem;C:\\WINDOWS\\System32\\WindowsPowerShell\\v1.0\\;C:\\Program Files\\Git\\cmd;C:\\Program Files (x86)\\Common Files\\Adobe\\AGL;C:\\Program Files\\Csound6_x64\\bin;C:\\Program Files (x86)\\GtkSharp\\2.12\\bin;C:\\Program Files\\Microsoft SQL Server\\130\\Tools\\Binn\\;C:\\Python27;C:\\Program Files\\dotnet\\;C:\\Program Files\\Anaconda3;C:\\Program Files\\Anaconda3\\Scripts;C:\\Program Files\\Anaconda3\\Library\\bin;C:\\Program Files\\PuTTY\\;C:\\Program Files\\Java\\jdk1.8.0_131\\jre;C:\\MinGW\\bin;C:\\HashiCorp\\Vagrant\\bin;C:\\Program Files (x86)\\Yarn\\bin;C:\\Program Files\\nodejs\\;D:\\Academics\\UF\\DreamTeam\\cocos2d-x\\templates;D:\\Academics\\UF\\DreamTeam\\cocos2d-x\\tools\\cocos2d-console\\bin;\\c
# ...
