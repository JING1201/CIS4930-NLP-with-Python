# %%
import nltk, re, pprint
from nltk import word_tokenize

# %% [markdown]
# # 3.1 Accessing Text from Web and Disk

# %% [markdown]
# ## Electronic books (txt)

# %%
from urllib import request
url = "http://www.gutenberg.org/files/2554/2554-0.txt"

# %%
response = request.urlopen(url)
raw = response.read().decode('utf8')
type(raw)
# Out:
# str

# %%
len(raw)
# Out:
# 1176965

# %%
raw[:75]
# Out:
# '\ufeffThe Project Gutenberg EBook of Crime and Punishment, by Fyodor Dostoevsky\r'

# %%
# tokenization = break up the string into words and punctuations
tokens = word_tokenize(raw)
type(tokens)
# Out:
# list

# %%
len(tokens)
# Out:
# 257726

# %%
tokens[:50]
# Out:
# ['\ufeffThe',
#  'Project',
#  'Gutenberg',
#  'EBook',
#  'of',
#  'Crime',
#  'and',
#  'Punishment',
#  ',',
#  'by',
#  'Fyodor',
#  'Dostoevsky',
#  'This',
#  'eBook',
#  'is',
#  'for',
#  'the',
#  'use',
#  'of',
#  'anyone',
#  'anywhere',
#  'at',
#  'no',
#  'cost',
#  'and',
#  'with',
#  'almost',
#  'no',
#  'restrictions',
#  'whatsoever',
#  '.',
#  'You',
#  'may',
#  'copy',
#  'it',
#  ',',
#  'give',
#  'it',
#  'away',
#  'or',
#  're-use',
#  'it',
#  'under',
#  'the',
#  'terms',
#  'of',
#  'the',
#  'Project',
#  'Gutenberg',
#  'License']

# %%
text = nltk.Text(tokens)

# %%
type(text)
# Out:
# nltk.text.Text

# %%
text[1024:1062]
# Out:
# ['an',
#  'exceptionally',
#  'hot',
#  'evening',
#  'early',
#  'in',
#  'July',
#  'a',
#  'young',
#  'man',
#  'came',
#  'out',
#  'of',
#  'the',
#  'garret',
#  'in',
#  'which',
#  'he',
#  'lodged',
#  'in',
#  'S.',
#  'Place',
#  'and',
#  'walked',
#  'slowly',
#  ',',
#  'as',
#  'though',
#  'in',
#  'hesitation',
#  ',',
#  'towards',
#  'K.',
#  'bridge',
#  '.',
#  'He',
#  'had',
#  'successfully']

# %%
text.collocations()
# Out:
# Katerina Ivanovna; Pyotr Petrovitch; Pulcheria Alexandrovna; Avdotya
# Romanovna; Rodion Romanovitch; Marfa Petrovna; Sofya Semyonovna; old
# woman; Project Gutenberg-tm; Porfiry Petrovitch; Amalia Ivanovna;
# great deal; young man; Nikodim Fomitch; Ilya Petrovitch; Project
# Gutenberg; Andrey Semyonovitch; Hay Market; Dmitri Prokofitch; Good
# heavens

# %%
raw.find("PART I")
# Out:
# 5336

# %%
raw.rfind("End of Project Gutenberg") # reverse find
# Out:
# 1157810

# %%
raw = raw[5338:1157743]
raw.find("PART I")
# Out:
# 195767

# %% [markdown]
# ## Html

# %%
url = "http://news.bbc.co.uk/2/hi/health/2284783.stm"
html = request.urlopen(url).read().decode('utf8')

# %%
html[:60]
# Out:
# '<!doctype html public "-//W3C//DTD HTML 4.0 Transitional//EN'

# %%
from bs4 import BeautifulSoup
raw = BeautifulSoup(html).get_text()
tokens = word_tokenize(raw)
tokens
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Program Files\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
# ['BBC',
#  'NEWS',
#  '|',
#  'Health',
#  '|',
#  'Blondes',
#  "'to",
#  'die',
#  'out',
#  'in',
#  '200',
#  "years'",
#  'NEWS',
#  'SPORT',
#  'WEATHER',
#  'WORLD',
#  'SERVICE',
#  'A-Z',
#  'INDEX',
#  'SEARCH',
#  'You',
#  'are',
#  'in',
#  ':',
#  'Health',
#  'News',
#  'Front',
#  'Page',
#  'Africa',
#  'Americas',
#  'Asia-Pacific',
# ...

# %%
tokens = tokens[110:390]
text = nltk.Text(tokens)
text.concordance('gene')
# Out:
# Displaying 4 of 4 matches:
#                                      gene . In order for a child to have blond
#  have blonde hair , it must have the gene on both sides of the family in the g
# ere is a disadvantage of having that gene or by chance . They do n't disappear
# des would disappear is if having the gene was a disadvantage and I do not thin

# %% [markdown]
# ## Search Engine Results
# - efficient for searching large quantity of text for relevant linguistic examples
# - check linguistic patterns
# - convenient for checking a theory
# - Shortcomings:
#     - limited search pattern
#     - inconsistent results

# %% [markdown]
# ## RSS Feeds

# %%
import feedparser
llog = feedparser.parse("http://languagelog.ldc.upenn.edu/nll/?feed=atom")

# %%
llog['feed']['title']
# Out:
# 'Language Log'

# %%
len(llog.entries)
# Out:
# 13

# %%
post = llog.entries[2]

# %%
post.title
# Out:
# '&quot;Wait, wait, don&#039;t orca me&quot;'

# %%
content = post.content[0].value
content[:70]
# Out:
# '<p>Yesterday\'s edition of the comedy radio news quiz "<a href="https:/'

# %%
raw = BeautifulSoup(content).get_text()
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Program Files\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
word_tokenize(raw)
# Out:
# ['Yesterday',
#  "'s",
#  'edition',
#  'of',
#  'the',
#  'comedy',
#  'radio',
#  'news',
#  'quiz',
#  '``',
#  'Wait',
#  ',',
#  'wait',
#  ',',
#  'do',
#  "n't",
#  'tell',
#  'me',
#  "''",
#  'featured',
#  'some',
#  'discussion',
#  'of',
#  'the',
#  'Talking',
#  'Orcas',
#  'story',
#  'that',
#  'Geoff',
#  'Pullum',
#  'discussed',
#  'a',
#  'few',
#  'days',
#  'ago',
#  'in',
#  '``',
#  'Orca',
#  'emits',
#  'speech-like',
#  'sound',
#  ';',
#  'reporters',
#  'go',
#  'insane',
#  "''",
#  ',',
#  '1/31/2018',
#  '.',
#  'The',
#  'whole',
#  'discussion',
#  'is',
#  'worth',
#  'a',
#  'listen',
#  ':',
#  'Your',
#  'browser',
#  'does',
#  'not',
#  'support',
#  'the',
#  'audio',
#  'element',
#  '.',
#  'Peter',
#  'Sagal',
#  "'s",
#  'closing',
#  'remark',
#  'is',
#  'especially',
#  'good',
#  ':',
#  'Your',
#  'browser',
#  'does',
#  'not',
#  'support',
#  'the',
#  'audio',
#  'element',
#  '.']

# %% [markdown]
# ## Local files

# %%
f = open('our_data.txt')

# %%
f.read()
# Out:
# 'data without new lineneed a \\ and n \n for a new line 5 1 5 3 4 8 3 5 2 3\n1'

# %%
f = open('our_data.txt','rU')
for line in f:
    print (line.strip())
# Out:
# data without new lineneed a \ and n
# for a new line 5 1 5 3 4 8 3 5 2 3
# 1
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: DeprecationWarning: 'U' mode is deprecated
#   if __name__ == '__main__':

# %%
path = nltk.data.find('corpora/gutenberg/melville-moby_dick.txt')
raw = open(path, 'r').read()

# %%
raw[:50]
# Out:
# '[Moby Dick by Herman Melville 1851]\n\n\nETYMOLOGY.\n\n'

# %%
#user input
s = input ("Prompt: ")
# Out:
# Prompt: On an exceptionally hot evening early in July

# %%
print ("You typed", len(word_tokenize(s)),"words.")
# Out:
# You typed 8 words.

# %% [markdown]
# ## NLP Pipeline
# http://www.nltk.org/images/pipeline1.png
# - html
# - ASCII
# - Text
# - Vocab

# %%
raw = open('1-24-2018 Temp.txt').read()
type(raw)
# Out:
# str

# %%
tokens = word_tokenize(raw)
type(tokens)
# Out:
# list

# %%
words = [w.lower() for w in tokens]
type(words)
# Out:
# list

# %%
vocab = sorted(set(words))
type(vocab)
# Out:
# list

# %% [markdown]
# # 3.2 Text Processing at the Lowest Level

# %%
circus = 'Monty Python\'s Flying Circus'
circus
# Out:
# "Monty Python's Flying Circus"

# %%
couplet = "Just testing "\
           "Another line"
print(couplet)
# Out:
# Just testingAnother line

# %%
couplet = ("Another text"
            "On another line")
print(couplet)
# Out:
# Another textOn another line

# %%
'very'+'very'
# Out:
# 'veryvery'

# %%
'very'*4
# Out:
# 'veryveryveryvery'

# %%
a = [1, 2, 3, 4, 5, 6, 7, 6, 5, 4, 3, 2, 1]
b = [' ' * 2 * (7 - i) + 'very' * i for i in a]
for line in b:
    print(line)
# Out:
#             very
#           veryvery
#         veryveryvery
#       veryveryveryvery
#     veryveryveryveryvery
#   veryveryveryveryveryvery
# veryveryveryveryveryveryvery
#   veryveryveryveryveryvery
#     veryveryveryveryvery
#       veryveryveryvery
#         veryveryvery
#           veryvery
#             very

# %%
#subtraction and division dont work with strings

# %%
from nltk.corpus import gutenberg
raw = gutenberg.raw('melville-moby_dick.txt')
fdist = nltk.FreqDist(ch.lower() for ch in raw if ch.isalpha())
fdist.most_common(5)
# Out:
# [('e', 117092), ('t', 87996), ('a', 77916), ('o', 69326), ('n', 65617)]

# %%
[char for (char, count) in fdist.most_common()]
# Out:
# ['e',
#  't',
#  'a',
#  'o',
#  'n',
#  'i',
#  's',
#  'h',
#  'r',
#  'l',
#  'd',
#  'u',
#  'm',
#  'c',
#  'w',
#  'f',
#  'g',
#  'p',
#  'b',
#  'y',
#  'v',
#  'k',
#  'q',
#  'j',
#  'x',
#  'z']

# %%
monty = 'Monty Python'
monty.find("Python")
# Out:
# 6

# %%
# Operations on strings summed in Table 3.2

# %% [markdown]
# - Strings are immutable
# - Lists are mutable

# %%
beatles = ['John','Paul','George','Ringo']
del beatles[-1]
beatles[0] = 'Jay'
beatles
# Out:
# ['Jay', 'Paul', 'George']

# %%
beatles = 'John Paul George Ringo'
beatles[0] = 'G'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-6a9bde761ba8> in <module>()
#       1 beatles = 'John Paul George Ringo'
# ----> 2 beatles[0] = 'G'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# # 3.3 Text Processing with Unicode

# %%
path = nltk.data.find('corpora/unicode_samples/polish-lat2.txt')

# %%
f = open(path, encoding='latin2')
for line in f:
    line = line.strip()
    print(line)
# Out:
# Pruska Biblioteka Państwowa. Jej dawne zbiory znane pod nazwą
# "Berlinka" to skarb kultury i sztuki niemieckiej. Przewiezione przez
# Niemców pod koniec II wojny światowej na Dolny Śląsk, zostały
# odnalezione po 1945 r. na terytorium Polski. Trafiły do Biblioteki
# Jagiellońskiej w Krakowie, obejmują ponad 500 tys. zabytkowych
# archiwaliów, m.in. manuskrypty Goethego, Mozarta, Beethovena, Bacha.

# %%
f = open(path, encoding = 'latin2')
for line in f:
    line = line.strip()
    print (line.encode('unicode_escape'))
# Out:
# b'Pruska Biblioteka Pa\\u0144stwowa. Jej dawne zbiory znane pod nazw\\u0105'
# b'"Berlinka" to skarb kultury i sztuki niemieckiej. Przewiezione przez'
# b'Niemc\\xf3w pod koniec II wojny \\u015bwiatowej na Dolny \\u015al\\u0105sk, zosta\\u0142y'
# b'odnalezione po 1945 r. na terytorium Polski. Trafi\\u0142y do Biblioteki'
# b'Jagiello\\u0144skiej w Krakowie, obejmuj\\u0105 ponad 500 tys. zabytkowych'
# b'archiwali\\xf3w, m.in. manuskrypty Goethego, Mozarta, Beethovena, Bacha.'

# %%
ord ('ń') #integer ordinal
# Out:
# 324

# %%
nacute = '\u0144'
nacute
# Out:
# 'ń'

# %%
nacute.encode('utf8')
# Out:
# b'\xc5\x84'

# %%
import unicodedata
lines = open(path, encoding = 'latin2').readlines()
line = lines[2]
print(line.encode('unicode_escape'))
# Out:
# b'Niemc\\xf3w pod koniec II wojny \\u015bwiatowej na Dolny \\u015al\\u0105sk, zosta\\u0142y\\n'

# %%
for c in line:
    if ord(c)>127:
        print('{} U+{:04x} {}'.format(c.encode('utf8'), ord(c), unicodedata.name(c)))
# Out:
# b'\xc3\xb3' U+00f3 LATIN SMALL LETTER O WITH ACUTE
# b'\xc5\x9b' U+015b LATIN SMALL LETTER S WITH ACUTE
# b'\xc5\x9a' U+015a LATIN CAPITAL LETTER S WITH ACUTE
# b'\xc4\x85' U+0105 LATIN SMALL LETTER A WITH OGONEK
# b'\xc5\x82' U+0142 LATIN SMALL LETTER L WITH STROKE

# %%
line.find('zosta\u0142y')
# Out:
# 54

# %%
line = line.lower()
line
# Out:
# 'niemców pod koniec ii wojny światowej na dolny śląsk, zostały\n'

# %%
line.encode('unicode_escape')
# Out:
# b'niemc\\xf3w pod koniec ii wojny \\u015bwiatowej na dolny \\u015bl\\u0105sk, zosta\\u0142y\\n'

# %%
import re
m = re.search('\u015b\w*',line)
m.group()
# Out:
# 'światowej'

# %%
word_tokenize(line)
# Out:
# ['niemców',
#  'pod',
#  'koniec',
#  'ii',
#  'wojny',
#  'światowej',
#  'na',
#  'dolny',
#  'śląsk',
#  ',',
#  'zostały']

# %% [markdown]
# # 3.4 Regular Expressions for Detecting Word Patterns

# %%
import re
wordlist = [w for w in nltk.corpus.words.words('en') if w.islower()]

# %%
[w for w in wordlist if re.search('ed$',w)]
# Out:
# ['abaissed',
#  'abandoned',
#  'abased',
#  'abashed',
#  'abatised',
#  'abed',
#  'aborted',
#  'abridged',
#  'abscessed',
#  'absconded',
#  'absorbed',
#  'abstracted',
#  'abstricted',
#  'accelerated',
#  'accepted',
#  'accidented',
#  'accoladed',
#  'accolated',
#  'accomplished',
#  'accosted',
#  'accredited',
#  'accursed',
#  'accused',
#  'accustomed',
#  'acetated',
#  'acheweed',
#  'aciculated',
#  'aciliated',
#  'acknowledged',
#  'acorned',
#  'acquainted',
#  'acquired',
#  'acquisited',
#  'acred',
#  'aculeated',
#  'addebted',
#  'added',
#  'addicted',
#  'addlebrained',
#  'addleheaded',
#  'addlepated',
#  'addorsed',
#  'adempted',
#  'adfected',
#  'adjoined',
#  'admired',
#  'admitted',
#  'adnexed',
#  'adopted',
#  'adossed',
#  'adreamed',
#  'adscripted',
#  'aduncated',
#  'advanced',
#  'advised',
#  'aeried',
#  'aethered',
#  'afeared',
#  'affected',
#  'affectioned',
#  'affined',
#  'afflicted',
#  'affricated',
#  'affrighted',
# ...

# %%
[w for w in wordlist if re.search('^..j..t..$',w)]
# Out:
# ['abjectly',
#  'adjuster',
#  'dejected',
#  'dejectly',
#  'injector',
#  'majestic',
#  'objectee',
#  'objector',
#  'rejecter',
#  'rejector',
#  'unjilted',
#  'unjolted',
#  'unjustly']

# %%
[w for w in wordlist if re.search('..j..t..',w)]
# Out:
# ['abjectedness',
#  'abjection',
#  'abjective',
#  'abjectly',
#  'abjectness',
#  'adjection',
#  'adjectional',
#  'adjectival',
#  'adjectivally',
#  'adjective',
#  'adjectively',
#  'adjectivism',
#  'adjectivitis',
#  'adjustable',
#  'adjustably',
#  'adjustage',
#  'adjustation',
#  'adjuster',
#  'adjustive',
#  'adjustment',
#  'antejentacular',
#  'antiprojectivity',
#  'bijouterie',
#  'coadjustment',
#  'cojusticiar',
#  'conjective',
#  'conjecturable',
#  'conjecturably',
#  'conjectural',
#  'conjecturalist',
#  'conjecturality',
#  'conjecturally',
#  'conjecture',
#  'conjecturer',
#  'coprojector',
#  'counterobjection',
#  'dejected',
#  'dejectedly',
#  'dejectedness',
#  'dejectile',
#  'dejection',
#  'dejectly',
#  'dejectory',
#  'dejecture',
#  'disjection',
#  'guanajuatite',
#  'inadjustability',
#  'inadjustable',
#  'injectable',
#  'injection',
#  'injector',
#  'injustice',
#  'insubjection',
#  'interjection',
#  'interjectional',
# ...

# %%
#? specifies that previous character is optional
[w for w in wordlist if re.search('^e-?mail$',w)]
# Out:
# []

# %%
# count occurrences
sum(1 for w in wordlist if re.search('^e-?mail$', w))
# Out:
# 0

# %% [markdown]
# ## Ranges and Closures
# - textonyms = two or more words that are entered with the same sequence of keystrokes
#     - ex. hole and golf (4653)

# %%
[w for w in wordlist if re.search('^[ghi][mno][jlk][def]$',w)]
# Out:
# ['gold', 'golf', 'hold', 'hole']

# %%
[w for w in wordlist if re.search('^[g-o]+$',w)]
#this is looking for words that only use keys 4,5,6
# Out:
# ['g',
#  'ghoom',
#  'gig',
#  'giggling',
#  'gigolo',
#  'gilim',
#  'gill',
#  'gilling',
#  'gilo',
#  'gim',
#  'gin',
#  'ging',
#  'gingili',
#  'gink',
#  'ginkgo',
#  'ginning',
#  'gio',
#  'glink',
#  'glom',
#  'glonoin',
#  'gloom',
#  'glooming',
#  'gnomon',
#  'go',
#  'gog',
#  'gogo',
#  'goi',
#  'going',
#  'gol',
#  'goli',
#  'gon',
#  'gong',
#  'gonion',
#  'goo',
#  'googol',
#  'gook',
#  'gool',
#  'goon',
#  'h',
#  'hi',
#  'high',
#  'hill',
#  'him',
#  'hin',
#  'hing',
#  'hinoki',
#  'ho',
#  'hog',
#  'hoggin',
#  'hogling',
#  'hoi',
#  'hoin',
#  'holing',
#  'holl',
#  'hollin',
#  'hollo',
#  'hollong',
#  'holm',
#  'homo',
#  'homologon',
#  'hong',
#  'honk',
#  'hook',
#  'hoon',
#  'i',
#  'igloo',
#  'ihi',
#  'ilk',
#  'ill',
#  'imi',
#  'imino',
#  'immi',
#  'in',
#  'ing',
#  'ingoing',
#  'inion',
#  'ink',
#  'inkling',
#  'inlook',
#  'inn',
#  'inning',
#  'io',
#  'ion',
#  'j',
#  'jhool',
#  'jig',
#  'jing',
#  'jingling',
# ...

# %%
[w for w in wordlist if re.search('^[a-fj-o]+$',w)]
# Out:
# ['a',
#  'aa',
#  'aal',
#  'aam',
#  'aba',
#  'abac',
#  'abaca',
#  'aback',
#  'abaff',
#  'abalone',
#  'abandon',
#  'abandonable',
#  'abandoned',
#  'abandonee',
#  'abb',
#  'abdal',
#  'abdomen',
#  'abeam',
#  'abed',
#  'abele',
#  'able',
#  'abloom',
#  'abode',
#  'abolla',
#  'aboma',
#  'aboon',
#  'academe',
#  'acana',
#  'acca',
#  'accede',
#  'accedence',
#  'accend',
#  'accolade',
#  'accoladed',
#  'accolle',
#  'accommodable',
#  'ace',
#  'ackman',
#  'acle',
#  'acme',
#  'acne',
#  'acnodal',
#  'acnode',
#  'acock',
#  'acold',
#  'acoma',
#  'acone',
#  'ad',
#  'adad',
#  'adance',
#  'add',
#  'adda',
#  'addable',
#  'added',
#  'addend',
#  'addenda',
#  'addle',
#  'ade',
#  'adead',
#  'adeem',
#  'adenocele',
#  'adenoma',
#  'adman',
#  'ado',
#  'adobe',
#  'ae',
#  'aefald',
#  'aenean',
#  'aeon',
#  'aface',
#  'affa',
#  'affable',
#  'aflame',
#  'afoam',
#  'ajaja',
#  'ak',
#  'aka',
#  'akala',
#  'ake',
#  'akeake',
#  'akee',
# ...

# %%
# function of +
chat_words = sorted(set(w for w in nltk.corpus.nps_chat.words()))
[w for w in chat_words if re.search('^m+i+n+e+$',w)]
# Out:
# ['miiiiiiiiiiiiinnnnnnnnnnneeeeeeeeee',
#  'miiiiiinnnnnnnnnneeeeeeee',
#  'mine',
#  'mmmmmmmmiiiiiiiiinnnnnnnnneeeeeeee']

# %%
[w for w in chat_words if re.search('^[ha]+$',w)]
# Out:
# ['a',
#  'aaaaaaaaaaaaaaaaa',
#  'aaahhhh',
#  'ah',
#  'ahah',
#  'ahahah',
#  'ahh',
#  'ahhahahaha',
#  'ahhh',
#  'ahhhh',
#  'ahhhhhh',
#  'ahhhhhhhhhhhhhh',
#  'h',
#  'ha',
#  'haaa',
#  'hah',
#  'haha',
#  'hahaaa',
#  'hahah',
#  'hahaha',
#  'hahahaa',
#  'hahahah',
#  'hahahaha',
#  'hahahahaaa',
#  'hahahahahaha',
#  'hahahahahahaha',
#  'hahahahahahahahahahahahahahahaha',
#  'hahahhahah',
#  'hahhahahaha']

# %%
#when ^ is the first character inside square brackets
# [^aeiouAEIOU] matches any character other than a vowel
[w for w in chat_words if re.search('^[^aeiouAEIOU]+$',w)]
# Out:
# ['!',
#  '!!',
#  '!!!',
#  '!!!!',
#  '!!!!!',
#  '!!!!!!',
#  '!!!!!!!',
#  '!!!!!!!!',
#  '!!!!!!!!!',
#  '!!!!!!!!!!',
#  '!!!!!!!!!!!',
#  '!!!!!!!!!!!!!',
#  '!!!!!!!!!!!!!!!!',
#  '!!!!!!!!!!!!!!!!!!!!!!',
#  '!!!!!!!!!!!!!!!!!!!!!!!',
#  '!!!!!!!!!!!!!!!!!!!!!!!!!!!',
#  '!!!!!!!!!!!!!!!!!!!!!!!!!!!!',
#  '!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!',
#  '!!!!!!.',
#  '!!!!!.',
#  '!!!!....',
#  '!!!.',
#  '!!.',
#  '!!...',
#  '!.',
#  '!...',
#  '!=',
#  '!?',
#  '!??',
#  '!???',
#  '"',
#  '"...',
#  '"?',
#  '"s',
#  '#',
#  '###',
#  '####',
#  '$',
#  '$$',
#  '$27',
#  '&',
#  '&^',
#  "'",
#  "''",
#  "'.",
#  "'d",
#  "'ll",
#  "'m",
#  "'n'",
#  "'s",
#  '(',
#  '(((',
#  '((((',
#  '(((((',
#  '((((((',
#  '(((((((',
#  '((((((((',
#  '(((((((((',
#  '((((((((((',
#  '(((((((((((',
#  '((((((((((((',
#  '(((((((((((((',
#  '((((((((((((((',
#  '(((((((((((((((',
#  '(((((((((((((((((',
#  '((((((((((((((((((',
#  '((((((((((((((((((((',
# ...

# %%
#functions of \,{},(), and |

# %%
wsj=sorted(set(nltk.corpus.treebank.words()))

# %%
[w for w in wsj if re.search('^[0-9]+\.[0-9]+$',w)]
# Out:
# ['0.0085',
#  '0.05',
#  '0.1',
#  '0.16',
#  '0.2',
#  '0.25',
#  '0.28',
#  '0.3',
#  '0.4',
#  '0.5',
#  '0.50',
#  '0.54',
#  '0.56',
#  '0.60',
#  '0.7',
#  '0.82',
#  '0.84',
#  '0.9',
#  '0.95',
#  '0.99',
#  '1.01',
#  '1.1',
#  '1.125',
#  '1.14',
#  '1.1650',
#  '1.17',
#  '1.18',
#  '1.19',
#  '1.2',
#  '1.20',
#  '1.24',
#  '1.25',
#  '1.26',
#  '1.28',
#  '1.35',
#  '1.39',
#  '1.4',
#  '1.457',
#  '1.46',
#  '1.49',
#  '1.5',
#  '1.50',
#  '1.55',
#  '1.56',
#  '1.5755',
#  '1.5805',
#  '1.6',
#  '1.61',
#  '1.637',
#  '1.64',
#  '1.65',
#  '1.7',
#  '1.75',
#  '1.76',
#  '1.8',
#  '1.82',
#  '1.8415',
#  '1.85',
#  '1.8500',
#  '1.9',
#  '1.916',
#  '1.92',
#  '10.19',
#  '10.2',
#  '10.5',
#  '107.03',
#  '107.9',
#  '109.73',
#  '11.10',
#  '11.5',
#  '11.57',
#  '11.6',
#  '11.72',
#  '11.95',
#  '112.9',
#  '113.2',
#  '116.3',
#  '116.4',
#  '116.7',
#  '116.9',
#  '118.6',
#  '12.09',
#  '12.5',
#  '12.52',
#  '12.68',
#  '12.7',
#  '12.82',
#  '12.97',
# ...

# %%
[w for w in wsj if re.search('^[A-Z]+\$$',w)]
# Out:
# ['C$', 'US$']

# %%
[w for w in wsj if re.search('^[0-9]{4}$',w)]
# Out:
# ['1614',
#  '1637',
#  '1787',
#  '1901',
#  '1903',
#  '1917',
#  '1925',
#  '1929',
#  '1933',
#  '1934',
#  '1948',
#  '1953',
#  '1955',
#  '1956',
#  '1961',
#  '1965',
#  '1966',
#  '1967',
#  '1968',
#  '1969',
#  '1970',
#  '1971',
#  '1972',
#  '1973',
#  '1975',
#  '1976',
#  '1977',
#  '1979',
#  '1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2005',
#  '2009',
#  '2017',
#  '2019',
#  '2029',
#  '3057',
#  '8300']

# %%
[w for w in wsj if re.search('^[0-9]+-[a-z]{3,5}$',w)]
# Out:
# ['10-day',
#  '10-lap',
#  '10-year',
#  '100-share',
#  '12-point',
#  '12-year',
#  '14-hour',
#  '15-day',
#  '150-point',
#  '190-point',
#  '20-point',
#  '20-stock',
#  '21-month',
#  '237-seat',
#  '240-page',
#  '27-year',
#  '30-day',
#  '30-point',
#  '30-share',
#  '30-year',
#  '300-day',
#  '36-day',
#  '36-store',
#  '42-year',
#  '50-state',
#  '500-stock',
#  '52-week',
#  '69-point',
#  '84-month',
#  '87-store',
#  '90-day']

# %%
[w for w in wsj if re.search('^[a-z]{5,}-[a-z]{2,3}-[a-z]{,6}$',w)]
# Out:
# ['black-and-white',
#  'bread-and-butter',
#  'father-in-law',
#  'machine-gun-toting',
#  'savings-and-loan']

# %%
[w for w in wsj if re.search('(ed|ing)$',w)]
# Out:
# ['62%-owned',
#  'Absorbed',
#  'According',
#  'Adopting',
#  'Advanced',
#  'Advancing',
#  'Alfred',
#  'Allied',
#  'Annualized',
#  'Anything',
#  'Arbitrage-related',
#  'Arbitraging',
#  'Asked',
#  'Assuming',
#  'Atlanta-based',
#  'Baking',
#  'Banking',
#  'Beginning',
#  'Beijing',
#  'Being',
#  'Bermuda-based',
#  'Betting',
#  'Boeing',
#  'Broadcasting',
#  'Bucking',
#  'Buying',
#  'Calif.-based',
#  'Change-ringing',
#  'Citing',
#  'Concerned',
#  'Confronted',
#  'Conn.based',
#  'Consolidated',
#  'Continued',
#  'Continuing',
#  'Declining',
#  'Defending',
#  'Depending',
#  'Designated',
#  'Determining',
#  'Developed',
#  'Died',
#  'During',
#  'Encouraged',
#  'Encouraging',
#  'English-speaking',
#  'Estimated',
#  'Everything',
#  'Excluding',
#  'Exxon-owned',
#  'Faulding',
#  'Fed',
#  'Feeding',
#  'Filling',
#  'Filmed',
#  'Financing',
#  'Following',
#  'Founded',
#  'Fracturing',
#  'Francisco-based',
#  'Fred',
#  'Funded',
#  'Funding',
# ...

# %% [markdown]
# ## See Table 3.3 for Regular Expression Meta-Characters

# %% [markdown]
# # 3.5 Useful Applications of Regular Expressions

# %%
word = 'supercalifragilisticexpialidocious'
re.findall(r'[aeiou]',word)
# Out:
# ['u',
#  'e',
#  'a',
#  'i',
#  'a',
#  'i',
#  'i',
#  'i',
#  'e',
#  'i',
#  'a',
#  'i',
#  'o',
#  'i',
#  'o',
#  'u']

# %%
len(re.findall(r'[aeiou]',word))
# Out:
# 16

# %%
fd = nltk.FreqDist(vs for word in wsj for vs in re.findall(r'[aeiou]{2,}',word))

# %%
fd.most_common(12)
# Out:
# [('io', 549),
#  ('ea', 476),
#  ('ie', 331),
#  ('ou', 329),
#  ('ai', 261),
#  ('ia', 253),
#  ('ee', 217),
#  ('oo', 174),
#  ('ua', 109),
#  ('au', 106),
#  ('ue', 105),
#  ('ui', 95)]

# %%
[int(n) for n in re.findall(r'([0-9]{2,4})','2009-12-31')]
# Out:
# [2009, 12, 31]

# %%
regexp = r'^[AEIOUaeiou]+|[AEIOUaeiou]+$|[^AEIOUaeiou]'
def compress(word):
    pieces = re.findall(regexp,word)
    return ''.join(pieces)
english_udhr = nltk.corpus.udhr.words('English-Latin1')
print(nltk.tokenwrap(compress(w) for w in english_udhr[:75]))
# Out:
# Unvrsl Dclrtn of Hmn Rghts Prmble Whrs rcgntn of the inhrnt dgnty and
# of the eql and inlnble rghts of all mmbrs of the hmn fmly is the fndtn
# of frdm , jstce and pce in the wrld , Whrs dsrgrd and cntmpt fr hmn
# rghts hve rsltd in brbrs acts whch hve outrgd the cnscnce of mnknd ,
# and the advnt of a wrld in whch hmn bngs shll enjy frdm of spch and

# %%
rotokas_words = nltk.corpus.toolbox.words('rotokas.dic')
cvs = [cv for w in rotokas_words for cv in re.findall(r'[ptksvr][aeiou]',w)]
cfd = nltk.ConditionalFreqDist(cvs)
cfd.tabulate()
# Out:
#     a   e   i   o   u
# k 418 148  94 420 173
# p  83  31 105  34  51
# r 187  63  84  89  79
# s   0   0 100   2   1
# t  47   8   0 148  37
# v  93  27 105  48  49

# %%
# to inspect the words befind the numbers in the table above
cv_word_pairs = [(cv,w) for w in rotokas_words
                for cv in re.findall(r'[ptksvr][aeiou]',w)]
cv_index = nltk.Index(cv_word_pairs) #convert list to Index?
cv_index['su']
# Out:
# ['kasuari']

# %%
cv_index['po']
# Out:
# ['kaapo',
#  'kaapopato',
#  'kaipori',
#  'kaiporipie',
#  'kaiporivira',
#  'kapo',
#  'kapoa',
#  'kapokao',
#  'kapokapo',
#  'kapokapo',
#  'kapokapoa',
#  'kapokapoa',
#  'kapokapora',
#  'kapokapora',
#  'kapokaporo',
#  'kapokaporo',
#  'kapokari',
#  'kapokarito',
#  'kapokoa',
#  'kapoo',
#  'kapooto',
#  'kapoovira',
#  'kapopaa',
#  'kaporo',
#  'kaporo',
#  'kaporopa',
#  'kaporoto',
#  'kapoto',
#  'karokaropo',
#  'karopo',
#  'kepo',
#  'kepoi',
#  'keposi',
#  'kepoto']

# %%
cv_index['si']
# Out:
# ['kaakasi',
#  'kaapisi',
#  'kaapisivira',
#  'kaereasi',
#  'kaereasivira',
#  'kapisi',
#  'kapisito',
#  'kapuasisi',
#  'kapuasisi',
#  'karavisi',
#  'karavisito',
#  'karisito',
#  'kasi',
#  'kasi',
#  'kasi',
#  'kasiarao',
#  'kasiava',
#  'kasikasi',
#  'kasikasi',
#  'Kasikasiua',
#  'Kasikasiua',
#  'kasipie',
#  'kasipu',
#  'kasipupie',
#  'kasipuvira',
#  'kasirao',
#  'kasiraopie',
#  'kasiraovira',
#  'kasiu',
#  'kasiura',
#  'kasivari',
#  'kausiopa',
#  'kausiovira',
#  'kavau asiava',
#  'kavesi',
#  'kavusi',
#  'keesi',
#  'kepisi',
#  'kepisiva',
#  'keposi',
#  'keravisi',
#  'keravisia',
#  'kerikerisi',
#  'kerisi',
#  'kerisito',
#  'kerisivira',
#  'kerosiri',
#  'kesi',
#  'kesie',
#  'kesievira',
#  'kesikea vaaguru',
#  'kesio',
#  'kesioto',
#  'kesivira',
#  'kevisi',
#  'kevoisi',
#  'kevoisivira',
#  'kikipisi',
#  'kikisi',
#  'kikisikae',
#  'kikisiova',
#  'kikitausi',
#  'koasio',
#  'koisi',
#  'koisiva',
#  'kokoisi',
#  'kokorosi',
# ...

# %% [markdown]
# ## Finding word stems

# %%
def stem(word):
    for suffix in ['ing', 'ly', 'ed', 'ious', 'ies', 'ive', 'es', 's', 'ment']:
        if word.endswith(suffix):
            return word[:-len(suffix)]
    return word

# %%
stem('interestingly')
# Out:
# 'interesting'

# %%
re.findall(r'^.*(ing|ly|ed|ious|ies|ive|es|s|ment)$', 'processing')
# Out:
# ['ing']

# %%
# use parentheses to specify scope of disjunction
# and then use ?: to not select the material to be output
re.findall(r'^.*(?:ing|ly|ed|ious|ies|ive|es|s|ment)$', 'processing')
# Out:
# ['processing']

# %%
# parenthesize both sides to create boundary
re.findall(r'^(.*)(ing|ly|ed|ious|ies|ive|es|s|ment)$', 'processing')
# Out:
# [('process', 'ing')]

# %%
re.findall(r'^(.*)(ing|ly|ed|ious|ies|ive|es|s|ment)$', 'processes')
# this doesnt work because the * tries to consume as much of the input as possible
# Out:
# [('processe', 's')]

# %%
#make the * operator non-greedy
# *?
re.findall(r'^(.*?)(ing|ly|ed|ious|ies|ive|es|s|ment)$', 'processes')
# Out:
# [('process', 'es')]

# %%
re.findall(r'^(.*?)(ing|ly|ed|ious|ies|ive|es|s|ment)?$', 'language')
# Out:
# [('language', '')]

# %%
def stem(word):
    regexp = r'^(.*?)(ing|ly|ed|ious|ies|ive|es|s|ment)?$'
    stem, suffix = re.findall(regexp, word)[0]
    return stem

# %%
raw = """DENNIS: Listen, strange women lying in ponds distributing swords is no basis for a system of government.  Supreme executive power derives from a mandate from the masses, not from some farcical aquatic ceremony."""

# %%
tokens = word_tokenize(raw)
[stem(t) for t in tokens]
# Out:
# ['DENNIS',
#  ':',
#  'Listen',
#  ',',
#  'strange',
#  'women',
#  'ly',
#  'in',
#  'pond',
#  'distribut',
#  'sword',
#  'i',
#  'no',
#  'basi',
#  'for',
#  'a',
#  'system',
#  'of',
#  'govern',
#  '.',
#  'Supreme',
#  'execut',
#  'power',
#  'deriv',
#  'from',
#  'a',
#  'mandate',
#  'from',
#  'the',
#  'mass',
#  ',',
#  'not',
#  'from',
#  'some',
#  'farcical',
#  'aquatic',
#  'ceremony',
#  '.']

# %% [markdown]
# ## Searching Tokenized Text

# %%
from nltk.corpus import gutenberg, nps_chat

# %%
moby = nltk.Text(gutenberg.words('melville-moby_dick.txt'))
moby.findall(r"<a> (<.*>) <man>")
# <> used to mark token boundaries
# Out:
# monied; nervous; dangerous; white; white; white; pious; queer; good;
# mature; white; Cape; great; wise; wise; butterless; white; fiendish;
# pale; furious; better; certain; complete; dismasted; younger; brave;
# brave; brave; brave

# %%
chat = nltk.Text(nps_chat.words())
chat.findall(r"<.*><.*><bro>")
# Out:
# you rule bro; telling you bro; u twizted bro

# %%
chat.findall(r"<l.*>{3,}")
# Out:
# lol lol lol; lmao lol lol; lol lol lol; la la la la la; la la la; la
# la la; lovely lol lol love; lol lol lol.; la la la; la la la

# %%
from nltk.corpus import brown
hobbies_learned = nltk.Text(brown.words(categories=['hobbies','learned']))
hobbies_learned.findall(r"<\w*><and><other><\w*s>")
# Out:
# speed and other activities; water and other liquids; tomb and other
# landmarks; Statues and other monuments; pearls and other jewels;
# charts and other items; roads and other features; figures and other
# objects; military and other areas; demands and other factors;
# abstracts and other compilations; iron and other metals

# %%
hobbies_learned.findall(r"<as><\w*><as><\w*>")
# Out:
# as accurately as possible; as well as the; as faithfully as possible;
# as much as what; as neat as a; as simple as you; as well as other; as
# well as other; as involved as determining; as well as other; as
# important as another; as accurately as possible; as accurate as any;
# as much as any; as different as a; as Orphic as that; as coppery as
# Delawares; as good as another; as large as small; as well as ease; as
# well as their; as well as possible; as straight as possible; as well
# as nailed; as smoothly as the; as soon as a; as well as injuries; as
# well as many; as well as reason; as well as in; as well as of; as well
# as a; as well as summer; as well as providing; as important as
# cooling; as evenly as it; as much as shading; as well as some; as well
# as subsoil; as high as possible; as well as many; as general as
# electrical; as long as the; as well as the; as much as was; as well as
# set; as well as by; as high as 15; as well as aid; as much as
# ...

# %% [markdown]
# # 3.6 Normalizing Text

# %%
raw = """DENNIS: Listen, strange women lying in ponds distributing swords is no basis for a system of government.  Supreme executive power derives from a mandate from the masses, not from some farcical aquatic ceremony."""
tokens = word_tokenize(raw)

# %% [markdown]
# ## Stemmers

# %%
porter = nltk.PorterStemmer()
lancaster = nltk.LancasterStemmer()
[porter.stem(t) for t in tokens]
# Out:
# ['denni',
#  ':',
#  'listen',
#  ',',
#  'strang',
#  'women',
#  'lie',
#  'in',
#  'pond',
#  'distribut',
#  'sword',
#  'is',
#  'no',
#  'basi',
#  'for',
#  'a',
#  'system',
#  'of',
#  'govern',
#  '.',
#  'suprem',
#  'execut',
#  'power',
#  'deriv',
#  'from',
#  'a',
#  'mandat',
#  'from',
#  'the',
#  'mass',
#  ',',
#  'not',
#  'from',
#  'some',
#  'farcic',
#  'aquat',
#  'ceremoni',
#  '.']

# %%
[lancaster.stem(t) for t in tokens]
# Out:
# ['den',
#  ':',
#  'list',
#  ',',
#  'strange',
#  'wom',
#  'lying',
#  'in',
#  'pond',
#  'distribut',
#  'sword',
#  'is',
#  'no',
#  'bas',
#  'for',
#  'a',
#  'system',
#  'of',
#  'govern',
#  '.',
#  'suprem',
#  'execut',
#  'pow',
#  'der',
#  'from',
#  'a',
#  'mand',
#  'from',
#  'the',
#  'mass',
#  ',',
#  'not',
#  'from',
#  'som',
#  'farc',
#  'aqu',
#  'ceremony',
#  '.']

# %%
class IndexedText(object):

    def __init__(self, stemmer, text):
        self._text = text
        self._stemmer = stemmer
        self._index = nltk.Index((self._stem(word), i)
                                 for (i, word) in enumerate(text))

    def concordance(self, word, width=40):
        key = self._stem(word)
        wc = int(width/4)                # words of context
        for i in self._index[key]:
            lcontext = ' '.join(self._text[i-wc:i])
            rcontext = ' '.join(self._text[i:i+wc])
            ldisplay = '{:>{width}}'.format(lcontext[-width:], width=width)
            rdisplay = '{:{width}}'.format(rcontext[:width], width=width)
            print(ldisplay, rdisplay)

    def _stem(self, word):
        return self._stemmer.stem(word).lower()

# %%
grail = nltk.corpus.webtext.words('grail.txt')
text = IndexedText(porter, grail)
text.concordance('lie')
# Out:
# r king ! DENNIS : Listen , strange women lying in ponds distributing swords is no
#  beat a very brave retreat . ROBIN : All lies ! MINSTREL : [ singing ] Bravest of
#        Nay . Nay . Come . Come . You may lie here . Oh , but you are wounded !
# doctors immediately ! No , no , please ! Lie down . [ clap clap ] PIGLET : Well
# ere is much danger , for beyond the cave lies the Gorge of Eternal Peril , which
#    you . Oh ... TIM : To the north there lies a cave -- the cave of Caerbannog --
# h it and lived ! Bones of full fifty men lie strewn about its lair . So , brave k
# not stop our fight ' til each one of you lies dead , and the Holy Grail returns t

# %% [markdown]
# ## Lemmatization

# %%
wnl = nltk.WordNetLemmatizer()
[wnl.lemmatize(t) for t in tokens]
# Out:
# ['DENNIS',
#  ':',
#  'Listen',
#  ',',
#  'strange',
#  'woman',
#  'lying',
#  'in',
#  'pond',
#  'distributing',
#  'sword',
#  'is',
#  'no',
#  'basis',
#  'for',
#  'a',
#  'system',
#  'of',
#  'government',
#  '.',
#  'Supreme',
#  'executive',
#  'power',
#  'derives',
#  'from',
#  'a',
#  'mandate',
#  'from',
#  'the',
#  'mass',
#  ',',
#  'not',
#  'from',
#  'some',
#  'farcical',
#  'aquatic',
#  'ceremony',
#  '.']

# %% [markdown]
# # 3.7 Regular Expressions for Tokenizing Text

# %%
 raw = """'When I'M a Duchess,' she said to herself, (not in a very hopeful tone though), 'I won't have any pepper in my kitchen AT ALL. Soup does very well without--Maybe it's always pepper that makes people hot-tempered,'..."""

# %%
re.split(r' ',raw)
# Out:
# ["'When",
#  "I'M",
#  'a',
#  "Duchess,'",
#  'she',
#  'said',
#  'to',
#  'herself,',
#  '(not',
#  'in',
#  'a',
#  'very',
#  'hopeful',
#  'tone',
#  'though),',
#  "'I",
#  "won't",
#  'have',
#  'any',
#  'pepper',
#  'in',
#  'my',
#  'kitchen',
#  'AT',
#  'ALL.',
#  'Soup',
#  'does',
#  'very',
#  'well',
#  'without--Maybe',
#  "it's",
#  'always',
#  'pepper',
#  'that',
#  'makes',
#  'people',
#  "hot-tempered,'..."]

# %%
re.split(r'[ \t\n]',raw)
# Out:
# ["'When",
#  "I'M",
#  'a',
#  "Duchess,'",
#  'she',
#  'said',
#  'to',
#  'herself,',
#  '(not',
#  'in',
#  'a',
#  'very',
#  'hopeful',
#  'tone',
#  'though),',
#  "'I",
#  "won't",
#  'have',
#  'any',
#  'pepper',
#  'in',
#  'my',
#  'kitchen',
#  'AT',
#  'ALL.',
#  'Soup',
#  'does',
#  'very',
#  'well',
#  'without--Maybe',
#  "it's",
#  'always',
#  'pepper',
#  'that',
#  'makes',
#  'people',
#  "hot-tempered,'..."]

# %%
re.split(r'\W+',raw) #\W refers to all characters other than letters, digits or underscore
# Out:
# ['',
#  'When',
#  'I',
#  'M',
#  'a',
#  'Duchess',
#  'she',
#  'said',
#  'to',
#  'herself',
#  'not',
#  'in',
#  'a',
#  'very',
#  'hopeful',
#  'tone',
#  'though',
#  'I',
#  'won',
#  't',
#  'have',
#  'any',
#  'pepper',
#  'in',
#  'my',
#  'kitchen',
#  'AT',
#  'ALL',
#  'Soup',
#  'does',
#  'very',
#  'well',
#  'without',
#  'Maybe',
#  'it',
#  's',
#  'always',
#  'pepper',
#  'that',
#  'makes',
#  'people',
#  'hot',
#  'tempered',
#  '']

# %%
re.findall(r'\w+|\S\w*', raw) #\S is non-whitespace character
# Out:
# ["'When",
#  'I',
#  "'M",
#  'a',
#  'Duchess',
#  ',',
#  "'",
#  'she',
#  'said',
#  'to',
#  'herself',
#  ',',
#  '(not',
#  'in',
#  'a',
#  'very',
#  'hopeful',
#  'tone',
#  'though',
#  ')',
#  ',',
#  "'I",
#  'won',
#  "'t",
#  'have',
#  'any',
#  'pepper',
#  'in',
#  'my',
#  'kitchen',
#  'AT',
#  'ALL',
#  '.',
#  'Soup',
#  'does',
#  'very',
#  'well',
#  'without',
#  '-',
#  '-Maybe',
#  'it',
#  "'s",
#  'always',
#  'pepper',
#  'that',
#  'makes',
#  'people',
#  'hot',
#  '-tempered',
#  ',',
#  "'",
#  '.',
#  '.',
#  '.']

# %%
print(re.findall(r"\w+(?:[-']\w+)*|'|[-.(]+|\S\w*", raw))
# Out:
# ["'", 'When', "I'M", 'a', 'Duchess', ',', "'", 'she', 'said', 'to', 'herself', ',', '(', 'not', 'in', 'a', 'very', 'hopeful', 'tone', 'though', ')', ',', "'", 'I', "won't", 'have', 'any', 'pepper', 'in', 'my', 'kitchen', 'AT', 'ALL', '.', 'Soup', 'does', 'very', 'well', 'without', '--', 'Maybe', "it's", 'always', 'pepper', 'that', 'makes', 'people', 'hot-tempered', ',', "'", '...']

# %% [markdown]
# ## NLTK's Regular Expression Tokenizer

# %%
text = 'That U.S.A. poster-print costs $12.40...'
pattern = r"(?x)([A-Z]\.)+| \w+( -\w+)*| \$?\d+(\.\d+)?%?| \.\.\.| [][.,;\"\'?():-_`]"

# %%
nltk.regexp_tokenize(text, pattern)
#DOESNT WORK
# Out:
# [('', '', ''),
#  ('A.', '', ''),
#  ('', '-print', ''),
#  ('', '', ''),
#  ('', '', '.40'),
#  ('', '', '')]

# %% [markdown]
# # 3.8 Segmentation

# %% [markdown]
# ## Sentence Segmentation

# %%
#average number of words in a sentence
len(nltk.corpus.brown.words())/len(nltk.corpus.brown.sents())
# Out:
# 20.250994070456922

# %%
text = nltk.corpus.gutenberg.raw('chesterton-thursday.txt')
sents = nltk.sent_tokenize(text)
pprint.pprint(sents[79:89])
# Out:
# ['"Nonsense!"',
#  'said Gregory, who was very rational when anyone else\nattempted paradox.',
#  '"Why do all the clerks and navvies in the\n'
#  'railway trains look so sad and tired, so very sad and tired?',
#  'I will\ntell you.',
#  'It is because they know that the train is going right.',
#  'It\n'
#  'is because they know that whatever place they have taken a ticket\n'
#  'for that place they will reach.',
#  'It is because after they have\n'
#  'passed Sloane Square they know that the next station must be\n'
#  'Victoria, and nothing but Victoria.',
#  'Oh, their wild rapture!',
#  'oh,\n'
#  'their eyes like stars and their souls again in Eden, if the next\n'
#  'station were unaccountably Baker Street!"',
#  '"It is you who are unpoetical," replied the poet Syme.']

# %% [markdown]
# ## Word Segmentation

# %%
text = "doyouseethekittyseethedoggydoyoulikethekittylikethedoggy"
seg1 = "0000000000000001000000000010000000000000000100000000000"
seg2 = "0100100100100001001001000010100100010010000100010010000"

# %%
def segment(text, segs):
    words = []
    last = 0
    for i in range(len(segs)):
        if segs[i] == '1':
            words.append(text[last:i+1])
            last = i+1
    words.append(text[last:])
    return words

# %%
segment(text,seg1)
# Out:
# ['doyouseethekitty', 'seethedoggy', 'doyoulikethekitty', 'likethedoggy']

# %%
segment(text, seg2)
# Out:
# ['do',
#  'you',
#  'see',
#  'the',
#  'kitty',
#  'see',
#  'the',
#  'doggy',
#  'do',
#  'you',
#  'like',
#  'the',
#  'kitty',
#  'like',
#  'the',
#  'doggy']

# %%
# objective function
'''
Calculation of Objective Function: Given a hypothetical 
segmentation of the source text (on the left), derive a 
lexicon and a derivation table that permit the source text 
to be reconstructed, then total up the number of characters 
used by each lexical item (including a boundary marker) and
the number of lexical items used by each derivation, 
to serve as a score of the quality of the segmentation; 
smaller values of the score indicate a better segmentation.
'''
# Out:
# '\nCalculation of Objective Function: Given a hypothetical \nsegmentation of the source text (on the left), derive a \nlexicon and a derivation table that permit the source text \nto be reconstructed, then total up the number of characters \nused by each lexical item (including a boundary marker) and\nthe number of lexical items used by each derivation, \nto serve as a score of the quality of the segmentation; \nsmaller values of the score indicate a better segmentation.\n'

# %%
def evaluate(text, segs):
    words = segment(text, segs)
    text_size = len(words)
    lexicon_size = sum(len(word) + 1 for word in set(words))
    return text_size + lexicon_size

# %%
text = "doyouseethekittyseethedoggydoyoulikethekittylikethedoggy"
seg1 = "0000000000000001000000000010000000000000000100000000000"
seg2 = "0100100100100001001001000010100100010010000100010010000"
seg3 = "0000100100000011001000000110000100010000001100010000001"

# %%
segment(text, seg3)
# Out:
# ['doyou',
#  'see',
#  'thekitt',
#  'y',
#  'see',
#  'thedogg',
#  'y',
#  'doyou',
#  'like',
#  'thekitt',
#  'y',
#  'like',
#  'thedogg',
#  'y']

# %%
evaluate(text, seg3)
# Out:
# 47

# %%
evaluate(text, seg2)
# Out:
# 48

# %%
evaluate(text, seg1)
# Out:
# 64

# %%
from random import randint

def flip(segs, pos):
    return segs[:pos] + str(1-int(segs[pos])) + segs[pos+1:]

def flip_n(segs, n):
    for i in range(n):
        segs = flip(segs, randint(0, len(segs)-1))
    return segs

def anneal(text, segs, iterations, cooling_rate):
    temperature = float(len(segs))
    while temperature > 0.5:
        best_segs, best = segs, evaluate(text, segs)
        for i in range(iterations):
            guess = flip_n(segs, round(temperature))
            score = evaluate(text, guess)
            if score < best:
                best, best_segs = score, guess
        score, segs = best, best_segs
        temperature = temperature / cooling_rate
        print(evaluate(text, segs), segment(text, segs))
    print()
    return segs

# %%
text = "doyouseethekittyseethedoggydoyoulikethekittylikethedoggy"
seg1 = "0000000000000001000000000010000000000000000100000000000"
anneal(text, seg1, 5000, 1.2)
# Out:
# 64 ['doyouseethekitty', 'seethedoggy', 'doyoulikethekitty', 'likethedoggy']
# 64 ['doyouseethekitty', 'seethedoggy', 'doyoulikethekitty', 'likethedoggy']
# 64 ['doyouseethekitty', 'seethedoggy', 'doyoulikethekitty', 'likethedoggy']
# 64 ['doyouseethekitty', 'seethedoggy', 'doyoulikethekitty', 'likethedoggy']
# 64 ['doyouseethekitty', 'seethedoggy', 'doyoulikethekitty', 'likethedoggy']
# 64 ['doyouseethekitty', 'seethedoggy', 'doyoulikethekitty', 'likethedoggy']
# 64 ['doyouseethekitty', 'seethedoggy', 'doyoulikethekitty', 'likethedoggy']
# 64 ['doyouseethekitty', 'seethedoggy', 'doyoulikethekitty', 'likethedoggy']
# 64 ['doyouseethekitty', 'seethedoggy', 'doyoulikethekitty', 'likethedoggy']
# 60 ['doy', 'ousee', 'thekitty', 'seethedoggy', 'doyou', 'like', 'thekitty', 'like', 'thedoggy']
# 56 ['doyou', 'see', 'thekitty', 'see', 'thedogg', 'y', 'doyou', 'like', 'thekitty', 'like', 'the', 'doggy']
# ...

# %%
silly = ['We', 'called', 'him', 'Tortoise', 'because', 'he', 'taught', 'us', '.']
' '.join(silly)
# Out:
# 'We called him Tortoise because he taught us .'

# %%
sentence = """hello
world"""
print(sentence)
# Out:
# hello
# world

# %%
sentence
# Out:
# 'hello\nworld'

# %%
fdist = nltk.FreqDist(['dog','cat','dog','cat','dog','snake','dog','cat'])
for word in sorted(fdist):
    print(word, '->', fdist[word], end='; ')
# Out:
# cat -> 3; dog -> 4; snake -> 1;

# %%
for word in sorted(fdist):
    print('{}->{};'.format(word, fdist[word]),end=' ')
# Out:
# cat->3; dog->4; snake->1;

# %%
'from {1} to {0}'.format('A',"B")
# Out:
# 'from B to A'

# %%
'{:6}'.format(41) #padded to width 6
# Out:
# '    41'

# %%
'{:<6}'.format(41) #aligned to the left
# Out:
# '41    '

# %%
'{:6}'.format('dog')
# Out:
# 'dog   '

# %%
'{:>6}'.format('dog') #aligned to the right
# Out:
# '   dog'

# %%
import math
'{:.4f}'.format(math.pi)
# Out:
# '3.1416'

# %%
"accuracy for {} words: {:.4%}".format(9375, 3205 / 9375)
#no need to multiply by 100
# Out:
# 'accuracy for 9375 words: 34.1867%'

# %%
def tabulate(cfdist, words, categories):
    print('{:16}'.format('Category'), end=' ')                    # column headings
    for word in words:
        print('{:>6}'.format(word), end=' ')
    print()
    for category in categories:
        print('{:16}'.format(category), end=' ')                  # row heading
        for word in words:                                        # for each word
            print('{:6}'.format(cfdist[category][word]), end=' ') # print table cell
        print()                                                   # end the row

# %%
from nltk.corpus import brown
cfd = nltk.ConditionalFreqDist(
        (genre, word)
        for genre in brown.categories()
        for word in brown.words(categories=genre))
genres = ['news', 'religion', 'hobbies', 'science_fiction', 'romance', 'humor']
modals = ['can', 'could', 'may', 'might', 'must', 'will']
tabulate(cfd, modals, genres)
# Out:
# Category            can  could    may  might   must   will
# news                 93     86     66     38     50    389
# religion             82     59     78     12     54     71
# hobbies             268     58    131     22     83    264
# science_fiction      16     49      4     12      8     16
# romance              74    193     11     51     45     43
# humor                16     30      8      8      9     13
